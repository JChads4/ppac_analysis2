# %%
import sys
import pandas as pd
import time as time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from matplotlib.lines import Line2D
import numba
import scienceplots
plt.style.use('science')

# %% [markdown]
# # Load data

# %%
# Main detectors
dssd = pd.read_csv('processed_data/dssd_non_vetoed_events.csv') # non-vetoed, calibrated dssd events 
ppac = pd.read_csv('processed_data/ppac_events.csv') # raw, uncalibrated
ruth = pd.read_csv('processed_data/rutherford_events.csv')

dssd = dssd.iloc[:len(dssd)//2]
ppac = ppac.iloc[:len(ppac)//2]
ruth = ruth.iloc[:len(ppac)//2]

# DSSD regions
imp = dssd[dssd['event_type'] == 'imp']
boxE = dssd[dssd['event_type'] == 'boxE']
boxW = dssd[dssd['event_type'] == 'boxW']
boxT = dssd[dssd['event_type'] == 'boxT']
boxB = dssd[dssd['event_type'] == 'boxB']

# PPAC 
cathode = ppac[ppac['detector'] == 'cathode']
anodeV = ppac[ppac['detector'] == 'anodeV']
anodeH = ppac[ppac['detector'] == 'anodeH']

# Rutherfords
ruth_E = ruth[ruth['detector'] == 'ruthE']
ruth_W = ruth[ruth['detector'] == 'ruthW']

# %% [markdown]
# # PPAC-SHREC coincidences

# %%
# Coincidence window
window_before_ns = 5000  # 1700 ns (1.7 us) before
window_after_ns = 0   # 1000 ns (1 us) after

# Convert to picoseconds for use with timetag values
window_before_ps = window_before_ns * 1000  # ns to ps
window_after_ps = window_after_ns * 1000    # ns to ps

# %%
# Sort dfs by time (should already be sorted)
cathode_sorted = cathode.sort_values('timetag').reset_index(drop=True)
anodeV_sorted = anodeV.sort_values('timetag').reset_index(drop=True)
anodeH_sorted = anodeH.sort_values('timetag').reset_index(drop=True)
imp_sorted = imp.sort_values('tagx').reset_index(drop=True)  # Using tagx for IMP

# %%
# Grab timetag vals (faster searching)
cathode_timetags = cathode_sorted['timetag'].values
anodeV_timetags = anodeV_sorted['timetag'].values
anodeH_timetags = anodeH_sorted['timetag'].values
imp_timetags = imp_sorted['tagx'].values  # Using tagx as the IMP timetag

# %%
# Function to find PPAC events within the time window
def find_events_in_window(imp_timetag, detector_timetags, window_before_ps, window_after_ps):
    """
    Find ppac events that occur within the specified time window around the IMP event.
    All time values are in picoseconds.
    
    Params:
    -----------
    imp_timetag : Timestamp of the IMP event in picoseconds
    detector_timetags : Array of detector timestamps in picoseconds
    window_before_ps : Time window before the IMP event in picoseconds
    window_after_ps : Time window after the IMP event in picoseconds
        
    Returns:
    --------
    Indices of events within the window
    """
    # Calculate the time bounds
    lower_bound = imp_timetag - window_before_ps  # Time window before IMP
    upper_bound = imp_timetag + window_after_ps   # Time window after IMP
    
    # Find all events within these bounds using binary search 
    lower_idx = np.searchsorted(detector_timetags, lower_bound)
    upper_idx = np.searchsorted(detector_timetags, upper_bound)
    
    if upper_idx > lower_idx:
        return list(range(lower_idx, upper_idx))
    return []

# Start timing the search
start_time = time.time()

# Create list to store coincident events
coincident_events = []
non_ppac_coincident_events = []

# Number of IMP events to process
total_imp_events = len(imp_sorted)
print(f"Processing {total_imp_events} IMP events...")

# For each IMP event, find coincident PPAC signals
for idx, imp_row in imp_sorted.iterrows():
    imp_timetag = imp_row['tagx'] # remember we are using tagx for the timetag here
    
    # Find ppac events in time window
    cathode_indices = find_events_in_window(imp_timetag, cathode_timetags, window_before_ps, window_after_ps)
    anodeV_indices = find_events_in_window(imp_timetag, anodeV_timetags, window_before_ps, window_after_ps)
    anodeH_indices = find_events_in_window(imp_timetag, anodeH_timetags, window_before_ps, window_after_ps)
    
    # Only proceed if we have coincidences in all three PPAC detectors - AND condition here
    if cathode_indices and anodeV_indices and anodeH_indices:
        
        # Find the closest event in each detector (smallest absolute time difference)
        cathode_diffs = np.abs(cathode_timetags[cathode_indices] - imp_timetag)
        anodeV_diffs = np.abs(anodeV_timetags[anodeV_indices] - imp_timetag)
        anodeH_diffs = np.abs(anodeH_timetags[anodeH_indices] - imp_timetag)
        
        closest_cathode_idx = cathode_indices[np.argmin(cathode_diffs)]
        closest_anodeV_idx = anodeV_indices[np.argmin(anodeV_diffs)]
        closest_anodeH_idx = anodeH_indices[np.argmin(anodeH_diffs)]
        
        # Get the corresponding rows
        cathode_data = cathode_sorted.iloc[closest_cathode_idx]
        anodeV_data = anodeV_sorted.iloc[closest_anodeV_idx]
        anodeH_data = anodeH_sorted.iloc[closest_anodeH_idx]
        
        # Calculate time difference values (in picoseconds)
        # +ve = PPAC after IMP, -ve = PPAC before IMP
        dt_cathode_ps = cathode_data['timetag'] - imp_timetag
        dt_anodeV_ps = anodeV_data['timetag'] - imp_timetag
        dt_anodeH_ps = anodeH_data['timetag'] - imp_timetag
        
        # Create event data dictionary with all relevant information
        event_data = {
            # IMP data
            'imp_timetag': imp_timetag,
            'imp_x': imp_row['x'],
            'imp_y': imp_row['y'],
            'imp_tagx': imp_row['tagx'],
            'imp_tagy': imp_row['tagy'],
            'imp_nfile': imp_row['nfile'],
            'imp_tdelta': imp_row['tdelta'],
            'imp_nX': imp_row['nX'],
            'imp_nY': imp_row['nY'],
            'imp_xE': imp_row['xE'],
            'imp_yE': imp_row['yE'],
            'xboard': imp_row['xboard'],
            'yboard': imp_row['yboard'],
            
            # Cathode data
            'cathode_timetag': cathode_data['timetag'],
            'cathode_energy': cathode_data['energy'],
            'cathode_board': cathode_data['board'],
            'cathode_channel': cathode_data['channel'],
            'cathode_nfile': cathode_data['nfile'],
            
            # AnodeV data
            'anodeV_timetag': anodeV_data['timetag'],
            'anodeV_energy': anodeV_data['energy'],
            'anodeV_board': anodeV_data['board'],
            'anodeV_channel': anodeV_data['channel'],
            'anodeV_nfile': anodeV_data['nfile'],
            
            # AnodeH data
            'anodeH_timetag': anodeH_data['timetag'],
            'anodeH_energy': anodeH_data['energy'],
            'anodeH_board': anodeH_data['board'],
            'anodeH_channel': anodeH_data['channel'],
            'anodeH_nfile': anodeH_data['nfile'],
            
            # Time difference values (in picoseconds)
            'dt_cathode_ps': dt_cathode_ps,
            'dt_anodeV_ps': dt_anodeV_ps,
            'dt_anodeH_ps': dt_anodeH_ps,
            
            # Convert to nanoseconds for convenience
            'dt_cathode_ns': dt_cathode_ps / 1000,
            'dt_anodeV_ns': dt_anodeV_ps / 1000,
            'dt_anodeH_ns': dt_anodeH_ps / 1000
        }
        
        coincident_events.append(event_data)
    else:
        non_coincident_data = {
            # IMP data
            'timetag': imp_timetag,
            't':imp_timetag / 1e12,
            'x': imp_row['x'],
            'y': imp_row['y'],
            'tagx': imp_row['tagx'],
            'tagy': imp_row['tagy'],
            'nfile': imp_row['nfile'],
            'tdelta': imp_row['tdelta'],
            'nX': imp_row['nX'],
            'nY': imp_row['nY'],
            'xE': imp_row['xE'],
            'yE': imp_row['yE'],
            'xboard': imp_row['xboard'],
            'yboard': imp_row['yboard'],
        }
        
        non_ppac_coincident_events.append(non_coincident_data)
        
        # TODO - Since we use an AND condition between the ppac plates, we need to add a condition in to
        #        make sure theres no ppac signal at all.
    
    # Print progress every 10,000 events
    if idx % 10000 == 0 and idx > 0:
        elapsed = time.time() - start_time
        events_per_sec = idx / elapsed
        remaining_time = (total_imp_events - idx) / events_per_sec if events_per_sec > 0 else 0
        print(f"Processed {idx}/{total_imp_events} events ({idx/total_imp_events*100:.1f}%) - Rate: {events_per_sec:.1f} events/sec - ETA: {remaining_time:.1f} sec")

# Create the df with coincident events
coincident_imp_df = pd.DataFrame(coincident_events)
non_coincident_imp_df = pd.DataFrame(non_ppac_coincident_events)
print(f"Found {len(coincident_imp_df)} coincidences within the window")

# Calculate total processing time
elapsed_time = time.time() - start_time
print(f"Total processing time: {elapsed_time:.2f} seconds")
print(f"Processing rate: {total_imp_events/elapsed_time:.1f} events/second")
# Out:
# Processing 3112966 IMP events...
# Processed 10000/3112966 events (0.3%) - Rate: 3715.4 events/sec - ETA: 835.2 sec
# Processed 20000/3112966 events (0.6%) - Rate: 5825.9 events/sec - ETA: 530.9 sec
# Processed 30000/3112966 events (1.0%) - Rate: 7218.1 events/sec - ETA: 427.1 sec
# Processed 40000/3112966 events (1.3%) - Rate: 8142.1 events/sec - ETA: 377.4 sec
# Processed 50000/3112966 events (1.6%) - Rate: 8830.7 events/sec - ETA: 346.9 sec
# Processed 60000/3112966 events (1.9%) - Rate: 9467.6 events/sec - ETA: 322.5 sec
# Processed 70000/3112966 events (2.2%) - Rate: 9987.2 events/sec - ETA: 304.7 sec
# Processed 80000/3112966 events (2.6%) - Rate: 10369.4 events/sec - ETA: 292.5 sec
# Processed 90000/3112966 events (2.9%) - Rate: 10722.6 events/sec - ETA: 281.9 sec
# Processed 100000/3112966 events (3.2%) - Rate: 11003.1 events/sec - ETA: 273.8 sec
# Processed 110000/3112966 events (3.5%) - Rate: 11225.0 events/sec - ETA: 267.5 sec
# Processed 120000/3112966 events (3.9%) - Rate: 11415.7 events/sec - ETA: 262.2 sec
# Processed 130000/3112966 events (4.2%) - Rate: 11595.8 events/sec - ETA: 257.2 sec
# Processed 140000/3112966 events (4.5%) - Rate: 11766.3 events/sec - ETA: 252.7 sec
# Processed 150000/3112966 events (4.8%) - Rate: 11917.9 events/sec - ETA: 248.6 sec
# Processed 160000/3112966 events (5.1%) - Rate: 12057.5 events/sec - ETA: 244.9 sec
# Processed 170000/3112966 events (5.5%) - Rate: 12179.9 events/sec - ETA: 241.6 sec
# Processed 180000/3112966 events (5.8%) - Rate: 12296.7 events/sec - ETA: 238.5 sec
# Processed 190000/3112966 events (6.1%) - Rate: 12417.5 events/sec - ETA: 235.4 sec
# Processed 200000/3112966 events (6.4%) - Rate: 12506.7 events/sec - ETA: 232.9 sec
# Processed 210000/3112966 events (6.7%) - Rate: 12597.1 events/sec - ETA: 230.4 sec
# Processed 220000/3112966 events (7.1%) - Rate: 12681.9 events/sec - ETA: 228.1 sec
# Processed 230000/3112966 events (7.4%) - Rate: 12739.0 events/sec - ETA: 226.3 sec
# Processed 240000/3112966 events (7.7%) - Rate: 12752.6 events/sec - ETA: 225.3 sec
# Processed 250000/3112966 events (8.0%) - Rate: 12807.9 events/sec - ETA: 223.5 sec
# Processed 260000/3112966 events (8.4%) - Rate: 12864.1 events/sec - ETA: 221.8 sec
# Processed 270000/3112966 events (8.7%) - Rate: 12841.1 events/sec - ETA: 221.4 sec
# Processed 280000/3112966 events (9.0%) - Rate: 12861.3 events/sec - ETA: 220.3 sec
# Processed 290000/3112966 events (9.3%) - Rate: 12880.6 events/sec - ETA: 219.2 sec
# Processed 300000/3112966 events (9.6%) - Rate: 12928.7 events/sec - ETA: 217.6 sec
# Processed 310000/3112966 events (10.0%) - Rate: 12976.5 events/sec - ETA: 216.0 sec
# Processed 320000/3112966 events (10.3%) - Rate: 13005.6 events/sec - ETA: 214.8 sec
# Processed 330000/3112966 events (10.6%) - Rate: 13036.1 events/sec - ETA: 213.5 sec
# Processed 340000/3112966 events (10.9%) - Rate: 13072.6 events/sec - ETA: 212.1 sec
# Processed 350000/3112966 events (11.2%) - Rate: 13098.8 events/sec - ETA: 210.9 sec
# Processed 360000/3112966 events (11.6%) - Rate: 13133.1 events/sec - ETA: 209.6 sec
# Processed 370000/3112966 events (11.9%) - Rate: 13154.2 events/sec - ETA: 208.5 sec
# Processed 380000/3112966 events (12.2%) - Rate: 13163.2 events/sec - ETA: 207.6 sec
# Processed 390000/3112966 events (12.5%) - Rate: 13155.2 events/sec - ETA: 207.0 sec
# Processed 400000/3112966 events (12.8%) - Rate: 13200.5 events/sec - ETA: 205.5 sec
# Processed 410000/3112966 events (13.2%) - Rate: 13226.4 events/sec - ETA: 204.4 sec
# Processed 420000/3112966 events (13.5%) - Rate: 13277.5 events/sec - ETA: 202.8 sec
# Processed 430000/3112966 events (13.8%) - Rate: 13318.0 events/sec - ETA: 201.5 sec
# Processed 440000/3112966 events (14.1%) - Rate: 13346.0 events/sec - ETA: 200.3 sec
# Processed 450000/3112966 events (14.5%) - Rate: 13387.3 events/sec - ETA: 198.9 sec
# Processed 460000/3112966 events (14.8%) - Rate: 13412.8 events/sec - ETA: 197.8 sec
# Processed 470000/3112966 events (15.1%) - Rate: 13455.6 events/sec - ETA: 196.4 sec
# Processed 480000/3112966 events (15.4%) - Rate: 13493.0 events/sec - ETA: 195.1 sec
# Processed 490000/3112966 events (15.7%) - Rate: 13465.6 events/sec - ETA: 194.8 sec
# Processed 500000/3112966 events (16.1%) - Rate: 13454.4 events/sec - ETA: 194.2 sec
# Processed 510000/3112966 events (16.4%) - Rate: 13443.1 events/sec - ETA: 193.6 sec
# Processed 520000/3112966 events (16.7%) - Rate: 13379.3 events/sec - ETA: 193.8 sec
# Processed 530000/3112966 events (17.0%) - Rate: 13370.6 events/sec - ETA: 193.2 sec
# Processed 540000/3112966 events (17.3%) - Rate: 13362.8 events/sec - ETA: 192.5 sec
# Processed 550000/3112966 events (17.7%) - Rate: 13356.7 events/sec - ETA: 191.9 sec
# Processed 560000/3112966 events (18.0%) - Rate: 13350.5 events/sec - ETA: 191.2 sec
# Processed 570000/3112966 events (18.3%) - Rate: 13342.0 events/sec - ETA: 190.6 sec
# Processed 580000/3112966 events (18.6%) - Rate: 13335.0 events/sec - ETA: 189.9 sec
# Processed 590000/3112966 events (19.0%) - Rate: 13325.8 events/sec - ETA: 189.3 sec
# Processed 600000/3112966 events (19.3%) - Rate: 13320.7 events/sec - ETA: 188.7 sec
# Processed 610000/3112966 events (19.6%) - Rate: 13316.9 events/sec - ETA: 188.0 sec
# Processed 620000/3112966 events (19.9%) - Rate: 13304.3 events/sec - ETA: 187.4 sec
# Processed 630000/3112966 events (20.2%) - Rate: 13287.0 events/sec - ETA: 186.9 sec
# Processed 640000/3112966 events (20.6%) - Rate: 13273.6 events/sec - ETA: 186.3 sec
# Processed 650000/3112966 events (20.9%) - Rate: 13261.0 events/sec - ETA: 185.7 sec
# Processed 660000/3112966 events (21.2%) - Rate: 13249.4 events/sec - ETA: 185.1 sec
# Processed 670000/3112966 events (21.5%) - Rate: 13238.7 events/sec - ETA: 184.5 sec
# Processed 680000/3112966 events (21.8%) - Rate: 13227.5 events/sec - ETA: 183.9 sec
# Processed 690000/3112966 events (22.2%) - Rate: 13215.9 events/sec - ETA: 183.3 sec
# Processed 700000/3112966 events (22.5%) - Rate: 13205.0 events/sec - ETA: 182.7 sec
# Processed 710000/3112966 events (22.8%) - Rate: 13215.4 events/sec - ETA: 181.8 sec
# Processed 720000/3112966 events (23.1%) - Rate: 13244.8 events/sec - ETA: 180.7 sec
# Processed 730000/3112966 events (23.5%) - Rate: 13274.0 events/sec - ETA: 179.5 sec
# Processed 740000/3112966 events (23.8%) - Rate: 13302.8 events/sec - ETA: 178.4 sec
# Processed 750000/3112966 events (24.1%) - Rate: 13323.3 events/sec - ETA: 177.4 sec
# Processed 760000/3112966 events (24.4%) - Rate: 13335.0 events/sec - ETA: 176.5 sec
# Processed 770000/3112966 events (24.7%) - Rate: 13351.6 events/sec - ETA: 175.5 sec
# Processed 780000/3112966 events (25.1%) - Rate: 13369.8 events/sec - ETA: 174.5 sec
# Processed 790000/3112966 events (25.4%) - Rate: 13366.4 events/sec - ETA: 173.8 sec
# Processed 800000/3112966 events (25.7%) - Rate: 13372.5 events/sec - ETA: 173.0 sec
# Processed 810000/3112966 events (26.0%) - Rate: 13371.8 events/sec - ETA: 172.2 sec
# Processed 820000/3112966 events (26.3%) - Rate: 13374.6 events/sec - ETA: 171.4 sec
# Processed 830000/3112966 events (26.7%) - Rate: 13380.7 events/sec - ETA: 170.6 sec
# Processed 840000/3112966 events (27.0%) - Rate: 13394.1 events/sec - ETA: 169.7 sec
# Processed 850000/3112966 events (27.3%) - Rate: 13413.1 events/sec - ETA: 168.7 sec
# Processed 860000/3112966 events (27.6%) - Rate: 13415.9 events/sec - ETA: 167.9 sec
# Processed 870000/3112966 events (27.9%) - Rate: 13432.4 events/sec - ETA: 167.0 sec
# Processed 880000/3112966 events (28.3%) - Rate: 13443.9 events/sec - ETA: 166.1 sec
# Processed 890000/3112966 events (28.6%) - Rate: 13455.7 events/sec - ETA: 165.2 sec
# Processed 900000/3112966 events (28.9%) - Rate: 13465.9 events/sec - ETA: 164.3 sec
# Processed 910000/3112966 events (29.2%) - Rate: 13456.5 events/sec - ETA: 163.7 sec
# Processed 920000/3112966 events (29.6%) - Rate: 13466.1 events/sec - ETA: 162.9 sec
# Processed 930000/3112966 events (29.9%) - Rate: 13460.8 events/sec - ETA: 162.2 sec
# Processed 940000/3112966 events (30.2%) - Rate: 13450.0 events/sec - ETA: 161.6 sec
# Processed 950000/3112966 events (30.5%) - Rate: 13443.7 events/sec - ETA: 160.9 sec
# Processed 960000/3112966 events (30.8%) - Rate: 13437.9 events/sec - ETA: 160.2 sec
# Processed 970000/3112966 events (31.2%) - Rate: 13432.2 events/sec - ETA: 159.5 sec
# Processed 980000/3112966 events (31.5%) - Rate: 13426.4 events/sec - ETA: 158.9 sec
# Processed 990000/3112966 events (31.8%) - Rate: 13420.6 events/sec - ETA: 158.2 sec
# Processed 1000000/3112966 events (32.1%) - Rate: 13414.2 events/sec - ETA: 157.5 sec
# Processed 1010000/3112966 events (32.4%) - Rate: 13399.4 events/sec - ETA: 156.9 sec
# Processed 1020000/3112966 events (32.8%) - Rate: 13386.1 events/sec - ETA: 156.4 sec
# Processed 1030000/3112966 events (33.1%) - Rate: 13370.8 events/sec - ETA: 155.8 sec
# Processed 1040000/3112966 events (33.4%) - Rate: 13356.1 events/sec - ETA: 155.2 sec
# Processed 1050000/3112966 events (33.7%) - Rate: 13340.1 events/sec - ETA: 154.6 sec
# Processed 1060000/3112966 events (34.1%) - Rate: 13326.2 events/sec - ETA: 154.1 sec
# Processed 1070000/3112966 events (34.4%) - Rate: 13312.4 events/sec - ETA: 153.5 sec
# Processed 1080000/3112966 events (34.7%) - Rate: 13299.2 events/sec - ETA: 152.9 sec
# Processed 1090000/3112966 events (35.0%) - Rate: 13286.1 events/sec - ETA: 152.3 sec
# Processed 1100000/3112966 events (35.3%) - Rate: 13281.6 events/sec - ETA: 151.6 sec
# Processed 1110000/3112966 events (35.7%) - Rate: 13297.1 events/sec - ETA: 150.6 sec
# Processed 1120000/3112966 events (36.0%) - Rate: 13313.8 events/sec - ETA: 149.7 sec
# Processed 1130000/3112966 events (36.3%) - Rate: 13330.6 events/sec - ETA: 148.8 sec
# Processed 1140000/3112966 events (36.6%) - Rate: 13346.7 events/sec - ETA: 147.8 sec
# Processed 1150000/3112966 events (36.9%) - Rate: 13363.4 events/sec - ETA: 146.9 sec
# Processed 1160000/3112966 events (37.3%) - Rate: 13379.0 events/sec - ETA: 146.0 sec
# Processed 1170000/3112966 events (37.6%) - Rate: 13394.5 events/sec - ETA: 145.1 sec
# Processed 1180000/3112966 events (37.9%) - Rate: 13410.2 events/sec - ETA: 144.1 sec
# Processed 1190000/3112966 events (38.2%) - Rate: 13425.1 events/sec - ETA: 143.2 sec
# Processed 1200000/3112966 events (38.5%) - Rate: 13439.1 events/sec - ETA: 142.3 sec
# Processed 1210000/3112966 events (38.9%) - Rate: 13454.0 events/sec - ETA: 141.4 sec
# Processed 1220000/3112966 events (39.2%) - Rate: 13468.6 events/sec - ETA: 140.5 sec
# Processed 1230000/3112966 events (39.5%) - Rate: 13483.0 events/sec - ETA: 139.7 sec
# Processed 1240000/3112966 events (39.8%) - Rate: 13496.9 events/sec - ETA: 138.8 sec
# Processed 1250000/3112966 events (40.2%) - Rate: 13511.0 events/sec - ETA: 137.9 sec
# Processed 1260000/3112966 events (40.5%) - Rate: 13524.9 events/sec - ETA: 137.0 sec
# Processed 1270000/3112966 events (40.8%) - Rate: 13538.0 events/sec - ETA: 136.1 sec
# Processed 1280000/3112966 events (41.1%) - Rate: 13551.5 events/sec - ETA: 135.3 sec
# Processed 1290000/3112966 events (41.4%) - Rate: 13564.6 events/sec - ETA: 134.4 sec
# Processed 1300000/3112966 events (41.8%) - Rate: 13577.5 events/sec - ETA: 133.5 sec
# Processed 1310000/3112966 events (42.1%) - Rate: 13590.4 events/sec - ETA: 132.7 sec
# Processed 1320000/3112966 events (42.4%) - Rate: 13603.1 events/sec - ETA: 131.8 sec
# Processed 1330000/3112966 events (42.7%) - Rate: 13615.6 events/sec - ETA: 131.0 sec
# Processed 1340000/3112966 events (43.0%) - Rate: 13627.9 events/sec - ETA: 130.1 sec
# Processed 1350000/3112966 events (43.4%) - Rate: 13639.9 events/sec - ETA: 129.3 sec
# Processed 1360000/3112966 events (43.7%) - Rate: 13652.1 events/sec - ETA: 128.4 sec
# Processed 1370000/3112966 events (44.0%) - Rate: 13664.4 events/sec - ETA: 127.6 sec
# Processed 1380000/3112966 events (44.3%) - Rate: 13675.6 events/sec - ETA: 126.7 sec
# Processed 1390000/3112966 events (44.7%) - Rate: 13687.0 events/sec - ETA: 125.9 sec
# Processed 1400000/3112966 events (45.0%) - Rate: 13698.5 events/sec - ETA: 125.0 sec
# Processed 1410000/3112966 events (45.3%) - Rate: 13709.8 events/sec - ETA: 124.2 sec
# Processed 1420000/3112966 events (45.6%) - Rate: 13721.0 events/sec - ETA: 123.4 sec
# Processed 1430000/3112966 events (45.9%) - Rate: 13731.1 events/sec - ETA: 122.6 sec
# Processed 1440000/3112966 events (46.3%) - Rate: 13741.8 events/sec - ETA: 121.7 sec
# Processed 1450000/3112966 events (46.6%) - Rate: 13751.8 events/sec - ETA: 120.9 sec
# Processed 1460000/3112966 events (46.9%) - Rate: 13762.6 events/sec - ETA: 120.1 sec
# Processed 1470000/3112966 events (47.2%) - Rate: 13769.8 events/sec - ETA: 119.3 sec
# Processed 1480000/3112966 events (47.5%) - Rate: 13779.7 events/sec - ETA: 118.5 sec
# Processed 1490000/3112966 events (47.9%) - Rate: 13789.8 events/sec - ETA: 117.7 sec
# Processed 1500000/3112966 events (48.2%) - Rate: 13799.6 events/sec - ETA: 116.9 sec
# Processed 1510000/3112966 events (48.5%) - Rate: 13809.1 events/sec - ETA: 116.1 sec
# Processed 1520000/3112966 events (48.8%) - Rate: 13805.5 events/sec - ETA: 115.4 sec
# Processed 1530000/3112966 events (49.1%) - Rate: 13815.0 events/sec - ETA: 114.6 sec
# Processed 1540000/3112966 events (49.5%) - Rate: 13824.5 events/sec - ETA: 113.8 sec
# Processed 1550000/3112966 events (49.8%) - Rate: 13833.9 events/sec - ETA: 113.0 sec
# Processed 1560000/3112966 events (50.1%) - Rate: 13843.5 events/sec - ETA: 112.2 sec
# Processed 1570000/3112966 events (50.4%) - Rate: 13852.8 events/sec - ETA: 111.4 sec
# Processed 1580000/3112966 events (50.8%) - Rate: 13861.4 events/sec - ETA: 110.6 sec
# Processed 1590000/3112966 events (51.1%) - Rate: 13870.9 events/sec - ETA: 109.8 sec
# Processed 1600000/3112966 events (51.4%) - Rate: 13879.8 events/sec - ETA: 109.0 sec
# Processed 1610000/3112966 events (51.7%) - Rate: 13888.6 events/sec - ETA: 108.2 sec
# Processed 1620000/3112966 events (52.0%) - Rate: 13897.2 events/sec - ETA: 107.4 sec
# Processed 1630000/3112966 events (52.4%) - Rate: 13905.5 events/sec - ETA: 106.6 sec
# Processed 1640000/3112966 events (52.7%) - Rate: 13913.5 events/sec - ETA: 105.9 sec
# Processed 1650000/3112966 events (53.0%) - Rate: 13921.9 events/sec - ETA: 105.1 sec
# Processed 1660000/3112966 events (53.3%) - Rate: 13929.9 events/sec - ETA: 104.3 sec
# Processed 1670000/3112966 events (53.6%) - Rate: 13938.2 events/sec - ETA: 103.5 sec
# Processed 1680000/3112966 events (54.0%) - Rate: 13946.1 events/sec - ETA: 102.8 sec
# Processed 1690000/3112966 events (54.3%) - Rate: 13954.5 events/sec - ETA: 102.0 sec
# Processed 1700000/3112966 events (54.6%) - Rate: 13962.4 events/sec - ETA: 101.2 sec
# Processed 1710000/3112966 events (54.9%) - Rate: 13970.5 events/sec - ETA: 100.4 sec
# Processed 1720000/3112966 events (55.3%) - Rate: 13978.4 events/sec - ETA: 99.7 sec
# Processed 1730000/3112966 events (55.6%) - Rate: 13986.3 events/sec - ETA: 98.9 sec
# Processed 1740000/3112966 events (55.9%) - Rate: 13993.9 events/sec - ETA: 98.1 sec
# Processed 1750000/3112966 events (56.2%) - Rate: 14000.1 events/sec - ETA: 97.4 sec
# Processed 1760000/3112966 events (56.5%) - Rate: 14007.3 events/sec - ETA: 96.6 sec
# Processed 1770000/3112966 events (56.9%) - Rate: 14014.5 events/sec - ETA: 95.8 sec
# Processed 1780000/3112966 events (57.2%) - Rate: 14021.7 events/sec - ETA: 95.1 sec
# Processed 1790000/3112966 events (57.5%) - Rate: 14028.8 events/sec - ETA: 94.3 sec
# Processed 1800000/3112966 events (57.8%) - Rate: 14035.3 events/sec - ETA: 93.5 sec
# Processed 1810000/3112966 events (58.1%) - Rate: 14035.0 events/sec - ETA: 92.8 sec
# Processed 1820000/3112966 events (58.5%) - Rate: 14035.0 events/sec - ETA: 92.1 sec
# Processed 1830000/3112966 events (58.8%) - Rate: 14036.3 events/sec - ETA: 91.4 sec
# Processed 1840000/3112966 events (59.1%) - Rate: 14031.8 events/sec - ETA: 90.7 sec
# Processed 1850000/3112966 events (59.4%) - Rate: 14024.4 events/sec - ETA: 90.1 sec
# Processed 1860000/3112966 events (59.8%) - Rate: 14016.7 events/sec - ETA: 89.4 sec
# Processed 1870000/3112966 events (60.1%) - Rate: 14005.1 events/sec - ETA: 88.8 sec
# Processed 1880000/3112966 events (60.4%) - Rate: 13989.4 events/sec - ETA: 88.1 sec
# Processed 1890000/3112966 events (60.7%) - Rate: 13977.4 events/sec - ETA: 87.5 sec
# Processed 1900000/3112966 events (61.0%) - Rate: 13964.3 events/sec - ETA: 86.9 sec
# Processed 1910000/3112966 events (61.4%) - Rate: 13948.1 events/sec - ETA: 86.2 sec
# Processed 1920000/3112966 events (61.7%) - Rate: 13940.1 events/sec - ETA: 85.6 sec
# Processed 1930000/3112966 events (62.0%) - Rate: 13930.4 events/sec - ETA: 84.9 sec
# Processed 1940000/3112966 events (62.3%) - Rate: 13923.4 events/sec - ETA: 84.2 sec
# Processed 1950000/3112966 events (62.6%) - Rate: 13917.5 events/sec - ETA: 83.6 sec
# Processed 1960000/3112966 events (63.0%) - Rate: 13911.5 events/sec - ETA: 82.9 sec
# Processed 1970000/3112966 events (63.3%) - Rate: 13905.9 events/sec - ETA: 82.2 sec
# Processed 1980000/3112966 events (63.6%) - Rate: 13898.3 events/sec - ETA: 81.5 sec
# Processed 1990000/3112966 events (63.9%) - Rate: 13890.9 events/sec - ETA: 80.8 sec
# Processed 2000000/3112966 events (64.2%) - Rate: 13884.4 events/sec - ETA: 80.2 sec
# Processed 2010000/3112966 events (64.6%) - Rate: 13881.4 events/sec - ETA: 79.5 sec
# Processed 2020000/3112966 events (64.9%) - Rate: 13883.1 events/sec - ETA: 78.7 sec
# Processed 2030000/3112966 events (65.2%) - Rate: 13886.4 events/sec - ETA: 78.0 sec
# Processed 2040000/3112966 events (65.5%) - Rate: 13891.0 events/sec - ETA: 77.2 sec
# Processed 2050000/3112966 events (65.9%) - Rate: 13894.8 events/sec - ETA: 76.5 sec
# Processed 2060000/3112966 events (66.2%) - Rate: 13898.6 events/sec - ETA: 75.8 sec
# Processed 2070000/3112966 events (66.5%) - Rate: 13903.5 events/sec - ETA: 75.0 sec
# Processed 2080000/3112966 events (66.8%) - Rate: 13895.0 events/sec - ETA: 74.3 sec
# Processed 2090000/3112966 events (67.1%) - Rate: 13889.3 events/sec - ETA: 73.7 sec
# Processed 2100000/3112966 events (67.5%) - Rate: 13883.5 events/sec - ETA: 73.0 sec
# Processed 2110000/3112966 events (67.8%) - Rate: 13877.7 events/sec - ETA: 72.3 sec
# Processed 2120000/3112966 events (68.1%) - Rate: 13870.9 events/sec - ETA: 71.6 sec
# Processed 2130000/3112966 events (68.4%) - Rate: 13865.2 events/sec - ETA: 70.9 sec
# Processed 2140000/3112966 events (68.7%) - Rate: 13859.8 events/sec - ETA: 70.2 sec
# Processed 2150000/3112966 events (69.1%) - Rate: 13853.6 events/sec - ETA: 69.5 sec
# Processed 2160000/3112966 events (69.4%) - Rate: 13842.9 events/sec - ETA: 68.8 sec
# Processed 2170000/3112966 events (69.7%) - Rate: 13835.3 events/sec - ETA: 68.2 sec
# Processed 2180000/3112966 events (70.0%) - Rate: 13837.9 events/sec - ETA: 67.4 sec
# Processed 2190000/3112966 events (70.4%) - Rate: 13842.0 events/sec - ETA: 66.7 sec
# Processed 2200000/3112966 events (70.7%) - Rate: 13844.1 events/sec - ETA: 65.9 sec
# Processed 2210000/3112966 events (71.0%) - Rate: 13847.4 events/sec - ETA: 65.2 sec
# Processed 2220000/3112966 events (71.3%) - Rate: 13835.6 events/sec - ETA: 64.5 sec
# Processed 2230000/3112966 events (71.6%) - Rate: 13831.7 events/sec - ETA: 63.8 sec
# Processed 2240000/3112966 events (72.0%) - Rate: 13825.0 events/sec - ETA: 63.1 sec
# Processed 2250000/3112966 events (72.3%) - Rate: 13815.2 events/sec - ETA: 62.5 sec
# Processed 2260000/3112966 events (72.6%) - Rate: 13808.6 events/sec - ETA: 61.8 sec
# Processed 2270000/3112966 events (72.9%) - Rate: 13807.0 events/sec - ETA: 61.1 sec
# Processed 2280000/3112966 events (73.2%) - Rate: 13812.9 events/sec - ETA: 60.3 sec
# Processed 2290000/3112966 events (73.6%) - Rate: 13819.5 events/sec - ETA: 59.6 sec
# Processed 2300000/3112966 events (73.9%) - Rate: 13825.8 events/sec - ETA: 58.8 sec
# Processed 2310000/3112966 events (74.2%) - Rate: 13831.9 events/sec - ETA: 58.1 sec
# Processed 2320000/3112966 events (74.5%) - Rate: 13836.0 events/sec - ETA: 57.3 sec
# Processed 2330000/3112966 events (74.8%) - Rate: 13838.6 events/sec - ETA: 56.6 sec
# Processed 2340000/3112966 events (75.2%) - Rate: 13841.0 events/sec - ETA: 55.8 sec
# Processed 2350000/3112966 events (75.5%) - Rate: 13840.9 events/sec - ETA: 55.1 sec
# Processed 2360000/3112966 events (75.8%) - Rate: 13845.8 events/sec - ETA: 54.4 sec
# Processed 2370000/3112966 events (76.1%) - Rate: 13851.7 events/sec - ETA: 53.6 sec
# Processed 2380000/3112966 events (76.5%) - Rate: 13857.7 events/sec - ETA: 52.9 sec
# Processed 2390000/3112966 events (76.8%) - Rate: 13863.4 events/sec - ETA: 52.1 sec
# Processed 2400000/3112966 events (77.1%) - Rate: 13869.3 events/sec - ETA: 51.4 sec
# Processed 2410000/3112966 events (77.4%) - Rate: 13875.0 events/sec - ETA: 50.7 sec
# Processed 2420000/3112966 events (77.7%) - Rate: 13880.9 events/sec - ETA: 49.9 sec
# Processed 2430000/3112966 events (78.1%) - Rate: 13886.4 events/sec - ETA: 49.2 sec
# Processed 2440000/3112966 events (78.4%) - Rate: 13892.0 events/sec - ETA: 48.4 sec
# Processed 2450000/3112966 events (78.7%) - Rate: 13897.7 events/sec - ETA: 47.7 sec
# Processed 2460000/3112966 events (79.0%) - Rate: 13903.1 events/sec - ETA: 47.0 sec
# Processed 2470000/3112966 events (79.3%) - Rate: 13908.5 events/sec - ETA: 46.2 sec
# Processed 2480000/3112966 events (79.7%) - Rate: 13914.1 events/sec - ETA: 45.5 sec
# Processed 2490000/3112966 events (80.0%) - Rate: 13919.3 events/sec - ETA: 44.8 sec
# Processed 2500000/3112966 events (80.3%) - Rate: 13924.9 events/sec - ETA: 44.0 sec
# Processed 2510000/3112966 events (80.6%) - Rate: 13926.2 events/sec - ETA: 43.3 sec
# Processed 2520000/3112966 events (81.0%) - Rate: 13923.3 events/sec - ETA: 42.6 sec
# Processed 2530000/3112966 events (81.3%) - Rate: 13923.2 events/sec - ETA: 41.9 sec
# Processed 2540000/3112966 events (81.6%) - Rate: 13922.4 events/sec - ETA: 41.2 sec
# Processed 2550000/3112966 events (81.9%) - Rate: 13924.8 events/sec - ETA: 40.4 sec
# Processed 2560000/3112966 events (82.2%) - Rate: 13927.6 events/sec - ETA: 39.7 sec
# Processed 2570000/3112966 events (82.6%) - Rate: 13930.6 events/sec - ETA: 39.0 sec
# Processed 2580000/3112966 events (82.9%) - Rate: 13933.5 events/sec - ETA: 38.3 sec
# Processed 2590000/3112966 events (83.2%) - Rate: 13936.5 events/sec - ETA: 37.5 sec
# Processed 2600000/3112966 events (83.5%) - Rate: 13938.7 events/sec - ETA: 36.8 sec
# Processed 2610000/3112966 events (83.8%) - Rate: 13940.8 events/sec - ETA: 36.1 sec
# Processed 2620000/3112966 events (84.2%) - Rate: 13943.3 events/sec - ETA: 35.4 sec
# Processed 2630000/3112966 events (84.5%) - Rate: 13946.0 events/sec - ETA: 34.6 sec
# Processed 2640000/3112966 events (84.8%) - Rate: 13947.3 events/sec - ETA: 33.9 sec
# Processed 2650000/3112966 events (85.1%) - Rate: 13950.4 events/sec - ETA: 33.2 sec
# Processed 2660000/3112966 events (85.4%) - Rate: 13955.2 events/sec - ETA: 32.5 sec
# Processed 2670000/3112966 events (85.8%) - Rate: 13960.3 events/sec - ETA: 31.7 sec
# Processed 2680000/3112966 events (86.1%) - Rate: 13965.1 events/sec - ETA: 31.0 sec
# Processed 2690000/3112966 events (86.4%) - Rate: 13969.7 events/sec - ETA: 30.3 sec
# Processed 2700000/3112966 events (86.7%) - Rate: 13973.6 events/sec - ETA: 29.6 sec
# Processed 2710000/3112966 events (87.1%) - Rate: 13978.3 events/sec - ETA: 28.8 sec
# Processed 2720000/3112966 events (87.4%) - Rate: 13983.1 events/sec - ETA: 28.1 sec
# Processed 2730000/3112966 events (87.7%) - Rate: 13987.9 events/sec - ETA: 27.4 sec
# Processed 2740000/3112966 events (88.0%) - Rate: 13992.6 events/sec - ETA: 26.7 sec
# Processed 2750000/3112966 events (88.3%) - Rate: 13997.2 events/sec - ETA: 25.9 sec
# Processed 2760000/3112966 events (88.7%) - Rate: 14001.7 events/sec - ETA: 25.2 sec
# Processed 2770000/3112966 events (89.0%) - Rate: 14006.0 events/sec - ETA: 24.5 sec
# Processed 2780000/3112966 events (89.3%) - Rate: 14010.6 events/sec - ETA: 23.8 sec
# Processed 2790000/3112966 events (89.6%) - Rate: 14015.1 events/sec - ETA: 23.0 sec
# Processed 2800000/3112966 events (89.9%) - Rate: 14019.5 events/sec - ETA: 22.3 sec
# Processed 2810000/3112966 events (90.3%) - Rate: 14023.9 events/sec - ETA: 21.6 sec
# Processed 2820000/3112966 events (90.6%) - Rate: 14028.4 events/sec - ETA: 20.9 sec
# Processed 2830000/3112966 events (90.9%) - Rate: 14032.6 events/sec - ETA: 20.2 sec
# Processed 2840000/3112966 events (91.2%) - Rate: 14037.1 events/sec - ETA: 19.4 sec
# Processed 2850000/3112966 events (91.6%) - Rate: 14040.6 events/sec - ETA: 18.7 sec
# Processed 2860000/3112966 events (91.9%) - Rate: 14044.9 events/sec - ETA: 18.0 sec
# Processed 2870000/3112966 events (92.2%) - Rate: 14049.4 events/sec - ETA: 17.3 sec
# Processed 2880000/3112966 events (92.5%) - Rate: 14053.6 events/sec - ETA: 16.6 sec
# Processed 2890000/3112966 events (92.8%) - Rate: 14058.0 events/sec - ETA: 15.9 sec
# Processed 2900000/3112966 events (93.2%) - Rate: 14062.1 events/sec - ETA: 15.1 sec
# Processed 2910000/3112966 events (93.5%) - Rate: 14064.6 events/sec - ETA: 14.4 sec
# Processed 2920000/3112966 events (93.8%) - Rate: 14068.4 events/sec - ETA: 13.7 sec
# Processed 2930000/3112966 events (94.1%) - Rate: 14072.6 events/sec - ETA: 13.0 sec
# Processed 2940000/3112966 events (94.4%) - Rate: 14076.7 events/sec - ETA: 12.3 sec
# Processed 2950000/3112966 events (94.8%) - Rate: 14081.0 events/sec - ETA: 11.6 sec
# Processed 2960000/3112966 events (95.1%) - Rate: 14084.8 events/sec - ETA: 10.9 sec
# Processed 2970000/3112966 events (95.4%) - Rate: 14088.9 events/sec - ETA: 10.1 sec
# Processed 2980000/3112966 events (95.7%) - Rate: 14093.1 events/sec - ETA: 9.4 sec
# Processed 2990000/3112966 events (96.0%) - Rate: 14097.1 events/sec - ETA: 8.7 sec
# Processed 3000000/3112966 events (96.4%) - Rate: 14101.2 events/sec - ETA: 8.0 sec
# Processed 3010000/3112966 events (96.7%) - Rate: 14105.3 events/sec - ETA: 7.3 sec
# Processed 3020000/3112966 events (97.0%) - Rate: 14109.2 events/sec - ETA: 6.6 sec
# Processed 3030000/3112966 events (97.3%) - Rate: 14113.2 events/sec - ETA: 5.9 sec
# Processed 3040000/3112966 events (97.7%) - Rate: 14116.8 events/sec - ETA: 5.2 sec
# Processed 3050000/3112966 events (98.0%) - Rate: 14120.8 events/sec - ETA: 4.5 sec
# Processed 3060000/3112966 events (98.3%) - Rate: 14124.8 events/sec - ETA: 3.7 sec
# Processed 3070000/3112966 events (98.6%) - Rate: 14128.6 events/sec - ETA: 3.0 sec
# Processed 3080000/3112966 events (98.9%) - Rate: 14132.3 events/sec - ETA: 2.3 sec
# Processed 3090000/3112966 events (99.3%) - Rate: 14136.0 events/sec - ETA: 1.6 sec
# Processed 3100000/3112966 events (99.6%) - Rate: 14139.6 events/sec - ETA: 0.9 sec
# Processed 3110000/3112966 events (99.9%) - Rate: 14143.2 events/sec - ETA: 0.2 sec
# Found 0 coincidences within the window
# Total processing time: 228.96 seconds
# Processing rate: 13595.9 events/second

# %% [markdown]
# # Plot raw etof

# %%
if not coincident_imp_df.empty:
    # Convert ns time differences to us for plotting
    coincident_imp_df['dt_cathode_us'] = coincident_imp_df['dt_cathode_ns'] / 1000  # ns to μs
    coincident_imp_df['dt_anodeV_us'] = coincident_imp_df['dt_anodeV_ns'] / 1000    # ns to μs
    coincident_imp_df['dt_anodeH_us'] = coincident_imp_df['dt_anodeH_ns'] / 1000    # ns to μs
    
    plt.figure(figsize=(8, 4))
    fs = 18
    plt.scatter(coincident_imp_df['imp_xE'], coincident_imp_df['dt_anodeH_us'], 
                alpha=0.2, s=1, c='blue')
    plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
    plt.ylabel(r"AnodeH ToF ($\mu$s)", fontsize=fs)
    plt.title("Raw E-ToF", fontsize=fs+2)
    plt.xlim(0, 14000)
    plt.ylim(-1.7, -1.35)
    plt.grid(True, alpha=0.3)
    ax = plt.gca()
    ax.tick_params(axis='both', which='major', labelsize=fs-2)
#     plt.legend(fontsize=fs-4, frameon=True)
    plt.savefig("plots/raw_etof.pdf", dpi=1000)
else:
    print("No coincidences")
# Out:
# No coincidences

# %% [markdown]
# # Time correction for SHREC imp region boards

# %%
from matplotlib.lines import Line2D

# Get the recoil time in seconds
coincident_imp_df['t'] = coincident_imp_df['imp_timetag'] * 1e-12

# Define manual time offsets for the boards- board0 is master
manual_offsets = {
    0: 0,
    1: -0.045e-6,
    2: -0.065e-6,
    3: -0.085e-6,
    4: -0.105e-6,
    5: -0.125e-6,
}

# Calculate the corrected dt for the ppac plates in microseconds
# Staying consistent with xboard
coincident_imp_df['dt_anodeH_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_anodeH_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

coincident_imp_df['dt_anodeV_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_anodeV_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

coincident_imp_df['dt_cathode_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_cathode_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

# Get boards
boards = sorted(coincident_imp_df['xboard'].unique())

plt.figure(figsize=(30,18))
fs=30

plt.subplot(221)
colors = plt.cm.tab10(np.linspace(0, 1, len(boards)))
legend_handles = []

for board, color in zip(boards, colors):
    # Filter the df for this board
    board_data = coincident_imp_df[coincident_imp_df['xboard'] == board]
    plt.scatter(board_data['imp_xE'], board_data['dt_anodeH_us'],
                s=2, alpha=0.2, color=color, label=f'Board {board}')
    legend_handles.append(Line2D([0], [0], marker='o', color='w', markersize=14, markerfacecolor=color, label=f'Board {board}'))
plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
plt.ylabel(r"ToF ($\mu$s)", fontsize=fs)
plt.title("E-ToF by implant board", fontsize=fs+2)
plt.xlim(0, 14000)
plt.ylim(-1.7, -1.35)
plt.grid(True, alpha=0.3)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
plt.legend(handles=legend_handles, fontsize=fs-4, frameon=True, shadow=True, facecolor='white')

plt.subplot(222)
for board, color in zip(boards, colors):
    # Filter the DataFrame for this board
    board_data = coincident_imp_df[coincident_imp_df['xboard'] == board]
    plt.scatter(board_data['imp_xE'], board_data['dt_anodeH_us_corr'],
                s=2, alpha=0.1, color=color, label=f'Board {board}')
    legend_handles.append(Line2D([0], [0], marker='o', color='w', markersize=14, markerfacecolor=color, label=f'Board {board}'))
plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
plt.ylabel(r"ToF ($\mu$s)", fontsize=fs)
plt.title("Time corrected E-ToF by implant board", fontsize=fs+2)
plt.xlim(0, 14000)
plt.ylim(-1.7, -1.35)
plt.grid(True, alpha=0.3)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
# plt.legend(handles=legend_handles, fontsize=fs-4, frameon=True)


plt.savefig("plots/etof_by_board.png", dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
#       1 from matplotlib.lines import Line2D
#       3 # Get the recoil time in seconds
# ----> 4 coincident_imp_df['t'] = coincident_imp_df['imp_timetag'] * 1e-12
#       6 # Define manual time offsets for the boards- board0 is master
#       7 manual_offsets = {
#       8     0: 0,
#       9     1: -0.045e-6,
#    (...)
#      13     5: -0.125e-6,
#      14 }
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/myenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'imp_timetag'

# %% [markdown]
# # Decay events

# %%
# Set decay time window
min_corr_time = 0.00000001     # Minimum time after recoil to consider (in seconds)
max_corr_time = 20     # Maximum time after recoil to consider (in seconds)

# %%
# Build pixel history from the imp df & group the full implant event history by pixel (x,y)
pixel_groups = imp.groupby(['x', 'y'])
pixel_history = {pixel: group for pixel, group in pixel_groups}

# %%
# Create decay event list
decay_events = []

# %%
# For each recoil event, search for subsequent events in the same pixel from imp

# Create decay events list to hold events
decay_candidates = []  

# Loop through coincident imp (recoil-like) events
for recoil_idx, recoil in coincident_imp_df.iterrows():
    
    # Get the pixel for the recoil event
    pixel = (recoil['imp_x'], recoil['imp_y'])
    
    # Convert the recoil imp_timetag from picoseconds to seconds
    recoil_time_sec = recoil['imp_timetag'] / 1e12
    
    # Check if there are any events in the same pixel in the imp region df.
    if pixel not in pixel_history:
        continue  # Skip if no events are found for this pixel
    
    # Get the time sorted events for this pixel from imp
    pixel_df = pixel_history[pixel]
    
    # Get the pixel time values as a sorted array
    time_array = pixel_df['t'].values # This is in seconds
    
    # Define the lower and upper bounds for candidate decay events in seconds
    lower_bound = recoil_time_sec + min_corr_time
    upper_bound = recoil_time_sec + max_corr_time
    
    # Use binary search to find the index positions in the time array
    start_idx = np.searchsorted(time_array, lower_bound, side='left')
    end_idx = np.searchsorted(time_array, upper_bound, side='right')
    
    # If events exist in the correlation window, add them as candidate decay events
    if start_idx < end_idx:
        
        candidate_events = pixel_df.iloc[start_idx:end_idx].copy()
        
        # Record the associated recoil info for later
        candidate_events['recoil_index'] = recoil_idx 
        candidate_events['recoil_time_sec'] = recoil_time_sec
        decay_candidates.append(candidate_events) # add decay candidates to list

# Combine all candidate decay events into a single df
if decay_candidates:
    decay_candidates_df = pd.concat(decay_candidates, ignore_index=True)
else:
    decay_candidates_df = pd.DataFrame()

# Display the first few decay candidates
print(decay_candidates_df.head())

# %% [markdown]
# # PPAC Anticoincidence check for decays
#
# Check the candidate decay is in the non-coincident list, do this by merging on pixel?

# %%
# Check the unique (x, y, t) keys in each DataFrame
print("Decay candidates unique keys:", decay_candidates_df[['x', 'y', 't']].drop_duplicates().shape)
print("Non-coincident unique keys:", non_coincident_imp_df[['x', 'y', 't']].drop_duplicates().shape)

# %%
if not decay_candidates_df.empty:
    # Drop duplicate rows based on x and y in non_coincident_imp_df
    non_coincident_clean = non_coincident_imp_df[['x', 'y']].drop_duplicates()
    
    # every row in decay_candidates_df is kept, 
    # and we add data from non_coincident_clean where there is a match on x and y
    decay_candidates_df = decay_candidates_df.merge(
        non_coincident_clean, 
        on=['x', 'y'],
        how='left',
        indicator='ppac_flag'
    )
    
    # If an event from decay_candidates_df finds a matching row in non_coincident_clean, 
    # ppac_flag will be set to "both".
    # If there is no match (i.e. PPAC signal), ppac_flag will be 'left_only'
    decay_candidates_df['is_clean'] = decay_candidates_df['ppac_flag'] == 'both'

print(decay_candidates_df['is_clean'].value_counts())
print(decay_candidates_df.head())

# %% [markdown]
# # Decay KHS

# %%
# Find the log time between implant and decay event
decay_candidates_df['log_dt'] = np.log(abs(decay_candidates_df['t'] - decay_candidates_df['recoil_time_sec']))

# %%
# Plot the 2d KHS hist
fs = 18
plt.figure(figsize=(8,4))
plt.hist2d(decay_candidates_df['yE'], decay_candidates_df['log_dt'], 
           bins=((500),(50)), range=((0,10000),(-3,3)), cmin=1)
plt.xlabel('Decay energy (keV)', fontsize=fs)
plt.ylabel(r'Ln($\Delta$t/ s)/ 10 keV', fontsize=fs)
plt.title('Decay events: KHS vs energy', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4)
plt.savefig('plots/decay_khs.pdf', dpi=1000)

# %% [markdown]
# # EVR-a correlations

# %%
# Alpha energy, time gates
# Recoil energy gates

alpha_energy_min = 8100    # Minimum alpha energy (keV)
alpha_energy_max = 8400    # Maximum alpha energy (keV)

recoil_energy_min = 2000   # Minimum recoil energy (keV)
recoil_energy_max = 8099  # Maximum recoil energy (keV) 

alpha_corr_min = 0.08    # Minimum time difference in seconds 
alpha_corr_max = 10         # Maximum time difference in seconds

# %%
# Filter alpha candidates by energy
filtered_alpha_candidates = decay_candidates_df[
    (decay_candidates_df['xE'] >= alpha_energy_min) & 
    (decay_candidates_df['xE'] <= alpha_energy_max)
].copy()

# %%
# just making sure we have t
if 't' not in filtered_alpha_candidates.columns:
    filtered_alpha_candidates['t'] = filtered_alpha_candidates['timetag'] / 1e12

# %%
# for each alpha candidate, find the preceeding recoil in same pixel

# initialising cols in the df
filtered_alpha_candidates['closest_recoil_index'] = np.nan
filtered_alpha_candidates['recoil_time'] = np.nan
filtered_alpha_candidates['time_difference'] = np.nan
filtered_alpha_candidates['recoil_energy'] = np.nan

# loop through the alpha candidates
for idx, alpha in filtered_alpha_candidates.iterrows():
    pixel_x = alpha['x']
    pixel_y = alpha['y']
    alpha_time = alpha['t']
    
    # Retrieve all recoil events from the same pixel
    recoils_in_pixel = coincident_imp_df[
        (coincident_imp_df['imp_x'] == pixel_x) & (coincident_imp_df['imp_y'] == pixel_y)
    ]
    
    # apply recoil energy gate
    recoils_in_pixel = recoils_in_pixel[
        (recoils_in_pixel['imp_xE'] >= recoil_energy_min) &
        (recoils_in_pixel['imp_xE'] <= recoil_energy_max)
    ]
    
    # Only consider recoils that occurred before the alpha event
    recoils_before = recoils_in_pixel[recoils_in_pixel['t'] < alpha_time]
    
    if not recoils_before.empty:
        
        # its good to work with copies... compute the time difference between r-a
        recoils_before = recoils_before.copy()
        recoils_before['time_diff'] = alpha_time - recoils_before['t']
        
        # make sure the r-a fits in the coincidence window
        recoils_in_window = recoils_before[
            (recoils_before['time_diff'] >= alpha_corr_min) &
            (recoils_before['time_diff'] <= alpha_corr_max)
        ]
        
        if not recoils_in_window.empty:
            # there might be multiple correlations, so choose the one with the smallest time difference
            closest_recoil = recoils_in_window.loc[recoils_in_window['time_diff'].idxmin()]
            filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = closest_recoil.name
            filtered_alpha_candidates.at[idx, 'recoil_time'] = closest_recoil['t']
            filtered_alpha_candidates.at[idx, 'time_difference'] = closest_recoil['time_diff']
            filtered_alpha_candidates.at[idx, 'recoil_energy'] = closest_recoil['imp_xE']
        else:
            filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = np.nan
            filtered_alpha_candidates.at[idx, 'recoil_time'] = np.nan
            filtered_alpha_candidates.at[idx, 'time_difference'] = np.nan
            filtered_alpha_candidates.at[idx, 'recoil_energy'] = np.nan
    else:
        filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = np.nan
        filtered_alpha_candidates.at[idx, 'recoil_time'] = np.nan
        filtered_alpha_candidates.at[idx, 'time_difference'] = np.nan
        filtered_alpha_candidates.at[idx, 'recoil_energy'] = np.nan

# %%
# Build the correlation dataframe
correlated_events = filtered_alpha_candidates.dropna(subset=['recoil_time']).copy()
print("Number of correlated alpha-recoil events:", len(correlated_events))
print(correlated_events.head())

# %%
# Merge the recoil and alpha info together, and rename things for clarity
recoil_rename = {
    'imp_timetag': 'rec_timetag',
    'imp_x': 'rec_x',
    'imp_y': 'rec_y',
    'imp_tagx': 'rec_tagx',
    'imp_tagy': 'rec_tagy',
    'imp_nfile': 'rec_nfile',
    'imp_tdelta': 'rec_tdelta',
    'imp_nX': 'rec_nX',
    'imp_nY': 'rec_nY',
    'imp_xE': 'rec_xE',
    'imp_yE': 'rec_yE',
    'xboard': 'rec_xboard',
    'yboard': 'rec_yboard',
    'cathode_timetag': 'rec_cathode_timetag',
    'cathode_energy': 'rec_cathode_energy',
    'cathode_board': 'rec_cathode_board',
    'cathode_channel': 'rec_cathode_channel',
    'cathode_nfile': 'rec_cathode_nfile',
    'anodeV_timetag': 'rec_anodeV_timetag',
    'anodeV_energy': 'rec_anodeV_energy',
    'anodeV_board': 'rec_anodeV_board',
    'anodeV_channel': 'rec_anodeV_channel',
    'anodeV_nfile': 'rec_anodeV_nfile',
    'anodeH_timetag': 'rec_anodeH_timetag',
    'anodeH_energy': 'rec_anodeH_energy',
    'anodeH_board': 'rec_anodeH_board',
    'anodeH_channel': 'rec_anodeH_channel',
    'anodeH_nfile': 'rec_anodeH_nfile',
    'dt_cathode_ps': 'rec_dt_cathode_ps',
    'dt_anodeV_ps': 'rec_dt_anodeV_ps',
    'dt_anodeH_ps': 'rec_dt_anodeH_ps',
    'dt_cathode_ns': 'rec_dt_cathode_ns',
    'dt_anodeV_ns': 'rec_dt_anodeV_ns',
    'dt_anodeH_ns': 'rec_dt_anodeH_ns',
    'dt_cathode_us': 'rec_dt_cathode_us',
    'dt_anodeV_us': 'rec_dt_anodeV_us',
    'dt_anodeH_us': 'rec_dt_anodeH_us',
    't': 'rec_t',
    'dt_anodeH_us_corr': 'rec_dt_anodeH_us_corr',
    'dt_anodeV_us_corr': 'rec_dt_anodeV_us_corr',
    'dt_cathode_us_corr': 'rec_dt_cathode_us_corr'
}

alpha_rename = {
    't': 'alpha_t',
    'x': 'alpha_x',
    'y': 'alpha_y',
    'tagx': 'alpha_tagx',
    'tagy': 'alpha_tagy',
    'nfile': 'alpha_nfile',
    'xboard': 'alpha_xboard',
    'yboard': 'alpha_yboard',
    'tdelta': 'alpha_tdelta',
    'nX': 'alpha_nX',
    'nY': 'alpha_nY',
    'xE': 'alpha_xE',
    'yE': 'alpha_yE',
    'event_type': 'alpha_event_type',
    'recoil_index': 'alpha_recoil_index',
    'recoil_time_sec': 'alpha_recoil_time',
    'ppac_flag': 'alpha_ppac_flag',
    'is_clean': 'alpha_is_clean',
    'log_dt': 'alpha_log_dt',
    # Also include new computed cols
    'closest_recoil_index': 'alpha_closest_recoil_index',
    'recoil_time': 'alpha_recoil_time_calculated',
    'time_difference': 'alpha_time_difference',
    'recoil_energy': 'alpha_recoil_energy'
}

# Rename columns in the recoil df
recoil_df_renamed = coincident_imp_df.copy().rename(columns=recoil_rename)

# Rename columns in the alpha df
alpha_df_renamed = correlated_events.copy().rename(columns=alpha_rename)

# Merge the two dfs using the recoil index
final_correlated_df = alpha_df_renamed.merge(
    recoil_df_renamed,
    left_on='alpha_recoil_index',
    right_index=True,
    how='left'
)

# %%
# print some check stuff
print("Final correlated Events df:")
print(final_correlated_df.head())
print("Checking pixel matches (alpha vs. recoil):")
print(final_correlated_df[['alpha_x', 'alpha_y', 'rec_x', 'rec_y']].head())

# %% [markdown]
# # Plotting correlated stuff

# %%
# log decay time

final_correlated_df['log_dt'] = np.log10(np.abs(final_correlated_df['alpha_t'] - final_correlated_df['rec_t']))
final_correlated_df['rec_alpha_time'] =np.abs(final_correlated_df['alpha_t'] - final_correlated_df['rec_t'])
fs = 16
plt.figure(figsize=(13,7))

plt.subplot(221)
plt.scatter(final_correlated_df['alpha_xE'], final_correlated_df['rec_alpha_time'],
            s=10, color='red', alpha=0.7, label=r'Correlated $\alpha$')
plt.xlabel('SHREC alpha X-Energy (keV)', fontsize=fs)
# plt.ylabel(r'log(dt/s)', fontsize=fs)
plt.ylabel(r'Correlation time (s)', fontsize=fs)
plt.xlim(8100, 8400)
plt.yscale('log')
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4 )
plt.legend(fontsize=fs-4, loc='lower left', frameon=True)
plt.ylim(0.001,20)
plt.title(r'Correlation time vs $\alpha$ energy', fontsize=fs+2)

plt.subplot(222)
plt.hist2d(decay_candidates_df['xE'], decay_candidates_df['log_dt'], 
           bins=((500),(50)), range=((5000,10000),(-3,3)), cmin=1)
plt.fill_betweenx(y=[np.log(alpha_corr_min), np.log(alpha_corr_max)], x1=alpha_energy_min, x2=alpha_energy_max, 
                  color='g', alpha=0.2, label=r'$^{246}$Fm gate')
plt.xlabel('Decay energy (keV)', fontsize=fs)
plt.ylabel(r'Ln($\Delta$t/ s)/ 10 keV', fontsize=fs)
plt.title('Decay events: KHS vs energy', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4)
plt.legend(fontsize=fs-4, loc='upper left', frameon=True, facecolor='white', shadow=True)




plt.savefig('plots/log_time_corr_alphas.pdf', dpi=300)

# %%
# Correlated etof

plt.figure(figsize=(8,4))
fs = 18
plt.hexbin(coincident_imp_df['imp_xE'], coincident_imp_df['dt_anodeH_us_corr'], 
           gridsize=200, extent=(0, 10000, -1.7, -1.5), mincnt=1, cmap='viridis', alpha=0.7)
plt.scatter(final_correlated_df['rec_xE'], final_correlated_df['rec_dt_anodeH_us_corr'],
            color='red', alpha=0.4, s=20, label=r'$\alpha$-tagged')  
legend_marker = Line2D([0], [0], marker='o', color='w', markersize=6, 
                        markerfacecolor='red', label=r'$\alpha$-tagged')
plt.ylim(-1.625, -1.49)
plt.xlim(0, 10000)
plt.xlabel('SHREC implant energy (keV)', fontsize=fs)
plt.ylabel(r'ToF ($\mu$s/ 50keV)', fontsize=fs)
plt.title(r'$\alpha$-correlated E-ToF', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
plt.legend(handles=[legend_marker], loc='lower right', fontsize=fs-2, frameon=True, facecolor='white', shadow=True)
plt.savefig('plots/correlated_etof.pdf', dpi=300)

# %%
# correlated beam spot
plt.figure(figsize=(8,3))
fs = 18
plt.hist2d(final_correlated_df['rec_x'], final_correlated_df['rec_y'], 
           bins=((175),(61)), range=((-1,174),(-1,60)), cmin=1)
# plt.xlim(0, 10000)
plt.xlabel('x-strip', fontsize=fs)
plt.ylabel(r'y-strip', fontsize=fs)
plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
# plt.legend(loc='lower right', fontsize=fs-2, frameon=True)
plt.savefig('plots/correlated_stripX_stripY.pdf', dpi=300)

# %%
# beam spot projections
# correlated beam spot

plt.figure(figsize=(12,6))
fs = 18

plt.subplot(221)
plt.hist(final_correlated_df['rec_x'], histtype='step', bins=175, range=(-1,174))
plt.xlabel('x-strip', fontsize=fs)
plt.ylabel(r'Counts', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.subplot(222)
plt.hist(final_correlated_df['rec_y'], histtype='step',bins=60, range=(-1,59))
plt.xlabel('y-strip', fontsize=fs)
plt.ylabel(r'Counts', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)


plt.savefig('plots/correlated_beam_spot_projections.pdf', dpi=300)

# %%
# Recoil and alpha energies

plt.figure(figsize=(12,6))
fs = 18

plt.subplot(221)
plt.hist(final_correlated_df['alpha_xE'], histtype='step', bins=60, range=(8100,8400))
plt.xlabel('Alpha energy (keV)', fontsize=fs)
plt.ylabel(r'Counts/ 10keV', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.subplot(222)
plt.hist(final_correlated_df['rec_xE'], histtype='step',bins=175, range=(2000,9000))
plt.xlabel('Recoil energy (keV)', fontsize=fs)
plt.ylabel(r'Counts/ 40keV', fontsize=fs)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.savefig('plots/rec_alpha_energy_projections.pdf', dpi=300)
