# %%
import sys
import pandas as pd
import time as time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from matplotlib.lines import Line2D
import numba
import scienceplots
plt.style.use('science')

# %% [markdown]
# # Load data

# %%
# Define data types for memory efficiency
dssd_dtypes = {
    'event_type': 'category',  # assuming few unique event types
    'x': 'int32',
    'y': 'int32',
    'tagx': 'int64',
    'tagy': 'int64',
    'nfile': 'int16',
    'tdelta': 'float32',
    'nX': 'int16',
    'nY': 'int16',
    'xE': 'float32',
    'yE': 'float32',
    'xboard': 'int8',
    'yboard': 'int8',
}

ppac_dtypes = {
    'detector': 'category',
    'timetag': 'int64',
    'energy': 'float32',
    'board': 'int8',
    'channel': 'int8',
    'nfile': 'int16',
}

ruth_dtypes = {
    'detector': 'category',
    'timetag': 'int64',
    'energy': 'float32',
    'board': 'int8',
    'channel': 'int8',
    'nfile': 'int16',
}

# %%
dssd = pd.read_csv('processed_data/dssd_non_vetoed_events.csv', dtype=dssd_dtypes)
ppac = pd.read_csv('processed_data/ppac_events.csv', dtype=ppac_dtypes)
ruth = pd.read_csv('processed_data/rutherford_events.csv', dtype=ruth_dtypes)

# %%
# Main detectors
dssd = pd.read_csv('processed_data/dssd_non_vetoed_events.csv') # non-vetoed, calibrated dssd events 
ppac = pd.read_csv('processed_data/ppac_events.csv') # raw, uncalibrated
ruth = pd.read_csv('processed_data/rutherford_events.csv')

# DSSD regions
imp = dssd[dssd['event_type'] == 'imp']
boxE = dssd[dssd['event_type'] == 'boxE']
boxW = dssd[dssd['event_type'] == 'boxW']
boxT = dssd[dssd['event_type'] == 'boxT']
boxB = dssd[dssd['event_type'] == 'boxB']

# PPAC 
cathode = ppac[ppac['detector'] == 'cathode']
anodeV = ppac[ppac['detector'] == 'anodeV']
anodeH = ppac[ppac['detector'] == 'anodeH']

# Rutherfords
ruth_E = ruth[ruth['detector'] == 'ruthE']
ruth_W = ruth[ruth['detector'] == 'ruthW']

# %% [markdown]
# # PPAC-SHREC coincidences

# %%
# Coincidence window
window_before_ns = 1700  # 1700 ns (1.7 us) before
window_after_ns = 0   # 1000 ns (1 us) after

# Convert to picoseconds for use with timetag values
window_before_ps = window_before_ns * 1000  # ns to ps
window_after_ps = window_after_ns * 1000    # ns to ps

# %%
# Sort dfs by time (should already be sorted)
cathode_sorted = cathode.sort_values('timetag').reset_index(drop=True)
anodeV_sorted = anodeV.sort_values('timetag').reset_index(drop=True)
anodeH_sorted = anodeH.sort_values('timetag').reset_index(drop=True)
imp_sorted = imp.sort_values('tagx').reset_index(drop=True)  # Using tagx for IMP

# %%
# Grab timetag vals (faster searching)
cathode_timetags = cathode_sorted['timetag'].values
anodeV_timetags = anodeV_sorted['timetag'].values
anodeH_timetags = anodeH_sorted['timetag'].values
imp_timetags = imp_sorted['tagx'].values  # Using tagx as the IMP timetag

# %%
# Function to find PPAC events within the time window
def find_events_in_window(imp_timetag, detector_timetags, window_before_ps, window_after_ps):
    """
    Find ppac events that occur within the specified time window around the IMP event.
    All time values are in picoseconds.
    
    Params:
    -----------
    imp_timetag : Timestamp of the IMP event in picoseconds
    detector_timetags : Array of detector timestamps in picoseconds
    window_before_ps : Time window before the IMP event in picoseconds
    window_after_ps : Time window after the IMP event in picoseconds
        
    Returns:
    --------
    Indices of events within the window
    """
    # Calculate the time bounds
    lower_bound = imp_timetag - window_before_ps  # Time window before IMP
    upper_bound = imp_timetag + window_after_ps   # Time window after IMP
    
    # Find all events within these bounds using binary search 
    lower_idx = np.searchsorted(detector_timetags, lower_bound)
    upper_idx = np.searchsorted(detector_timetags, upper_bound)
    
    if upper_idx > lower_idx:
        return list(range(lower_idx, upper_idx))
    return []

# Start timing the search
start_time = time.time()

# Create list to store coincident events
coincident_events = []
non_ppac_coincident_events = []

# Number of IMP events to process
total_imp_events = len(imp_sorted)
print(f"Processing {total_imp_events} IMP events...")

# For each IMP event, find coincident PPAC signals
for idx, imp_row in imp_sorted.iterrows():
    imp_timetag = imp_row['tagx'] # remember we are using tagx for the timetag here
    
    # Find ppac events in time window
    cathode_indices = find_events_in_window(imp_timetag, cathode_timetags, window_before_ps, window_after_ps)
    anodeV_indices = find_events_in_window(imp_timetag, anodeV_timetags, window_before_ps, window_after_ps)
    anodeH_indices = find_events_in_window(imp_timetag, anodeH_timetags, window_before_ps, window_after_ps)
    
    # Only proceed if we have coincidences in all three PPAC detectors - AND condition here
    if cathode_indices and anodeV_indices and anodeH_indices:
        
        # Find the closest event in each detector (smallest absolute time difference)
        cathode_diffs = np.abs(cathode_timetags[cathode_indices] - imp_timetag)
        anodeV_diffs = np.abs(anodeV_timetags[anodeV_indices] - imp_timetag)
        anodeH_diffs = np.abs(anodeH_timetags[anodeH_indices] - imp_timetag)
        
        closest_cathode_idx = cathode_indices[np.argmin(cathode_diffs)]
        closest_anodeV_idx = anodeV_indices[np.argmin(anodeV_diffs)]
        closest_anodeH_idx = anodeH_indices[np.argmin(anodeH_diffs)]
        
        # Get the corresponding rows
        cathode_data = cathode_sorted.iloc[closest_cathode_idx]
        anodeV_data = anodeV_sorted.iloc[closest_anodeV_idx]
        anodeH_data = anodeH_sorted.iloc[closest_anodeH_idx]
        
        # Calculate time difference values (in picoseconds)
        # +ve = PPAC after IMP, -ve = PPAC before IMP
        dt_cathode_ps = cathode_data['timetag'] - imp_timetag
        dt_anodeV_ps = anodeV_data['timetag'] - imp_timetag
        dt_anodeH_ps = anodeH_data['timetag'] - imp_timetag
        
        # Create event data dictionary with all relevant information
        event_data = {
            # IMP data
            'imp_timetag': imp_timetag,
            'imp_x': imp_row['x'],
            'imp_y': imp_row['y'],
            'imp_tagx': imp_row['tagx'],
            'imp_tagy': imp_row['tagy'],
            'imp_nfile': imp_row['nfile'],
            'imp_tdelta': imp_row['tdelta'],
            'imp_nX': imp_row['nX'],
            'imp_nY': imp_row['nY'],
            'imp_xE': imp_row['xE'],
            'imp_yE': imp_row['yE'],
            'xboard': imp_row['xboard'],
            'yboard': imp_row['yboard'],
            
            # Cathode data
            'cathode_timetag': cathode_data['timetag'],
            'cathode_energy': cathode_data['energy'],
            'cathode_board': cathode_data['board'],
            'cathode_channel': cathode_data['channel'],
            'cathode_nfile': cathode_data['nfile'],
            
            # AnodeV data
            'anodeV_timetag': anodeV_data['timetag'],
            'anodeV_energy': anodeV_data['energy'],
            'anodeV_board': anodeV_data['board'],
            'anodeV_channel': anodeV_data['channel'],
            'anodeV_nfile': anodeV_data['nfile'],
            
            # AnodeH data
            'anodeH_timetag': anodeH_data['timetag'],
            'anodeH_energy': anodeH_data['energy'],
            'anodeH_board': anodeH_data['board'],
            'anodeH_channel': anodeH_data['channel'],
            'anodeH_nfile': anodeH_data['nfile'],
            
            # Time difference values (in picoseconds)
            'dt_cathode_ps': dt_cathode_ps,
            'dt_anodeV_ps': dt_anodeV_ps,
            'dt_anodeH_ps': dt_anodeH_ps,
            
            # Convert to nanoseconds for convenience
            'dt_cathode_ns': dt_cathode_ps / 1000,
            'dt_anodeV_ns': dt_anodeV_ps / 1000,
            'dt_anodeH_ns': dt_anodeH_ps / 1000
        }
        
        coincident_events.append(event_data)
    else:
        non_coincident_data = {
            # IMP data
            'timetag': imp_timetag,
            't':imp_timetag / 1e12,
            'x': imp_row['x'],
            'y': imp_row['y'],
            'tagx': imp_row['tagx'],
            'tagy': imp_row['tagy'],
            'nfile': imp_row['nfile'],
            'tdelta': imp_row['tdelta'],
            'nX': imp_row['nX'],
            'nY': imp_row['nY'],
            'xE': imp_row['xE'],
            'yE': imp_row['yE'],
            'xboard': imp_row['xboard'],
            'yboard': imp_row['yboard'],
        }
        
        non_ppac_coincident_events.append(non_coincident_data)
        
        # TODO - Since we use an AND condition between the ppac plates, we need to add a condition in to
        #        make sure theres no ppac signal at all.
    
    # Print progress every 10,000 events
    if idx % 10000 == 0 and idx > 0:
        elapsed = time.time() - start_time
        events_per_sec = idx / elapsed
        remaining_time = (total_imp_events - idx) / events_per_sec if events_per_sec > 0 else 0
        print(f"Processed {idx}/{total_imp_events} events ({idx/total_imp_events*100:.1f}%) - Rate: {events_per_sec:.1f} events/sec - ETA: {remaining_time:.1f} sec")

# Create the df with coincident events
coincident_imp_df = pd.DataFrame(coincident_events)
non_coincident_imp_df = pd.DataFrame(non_ppac_coincident_events)
print(f"Found {len(coincident_imp_df)} coincidences within the window")

# Calculate total processing time
elapsed_time = time.time() - start_time
print(f"Total processing time: {elapsed_time:.2f} seconds")
print(f"Processing rate: {total_imp_events/elapsed_time:.1f} events/second")
# Out:
# Processing 5786755 IMP events...
# Processed 10000/5786755 events (0.2%) - Rate: 3123.5 events/sec - ETA: 1849.4 sec
# Processed 20000/5786755 events (0.3%) - Rate: 5054.9 events/sec - ETA: 1140.8 sec
# Processed 30000/5786755 events (0.5%) - Rate: 6449.4 events/sec - ETA: 892.6 sec
# Processed 40000/5786755 events (0.7%) - Rate: 7542.4 events/sec - ETA: 761.9 sec
# Processed 50000/5786755 events (0.9%) - Rate: 8368.5 events/sec - ETA: 685.5 sec
# Processed 60000/5786755 events (1.0%) - Rate: 9038.7 events/sec - ETA: 633.6 sec
# Processed 70000/5786755 events (1.2%) - Rate: 9591.5 events/sec - ETA: 596.0 sec
# Processed 80000/5786755 events (1.4%) - Rate: 10057.4 events/sec - ETA: 567.4 sec
# Processed 90000/5786755 events (1.6%) - Rate: 10181.3 events/sec - ETA: 559.5 sec
# Processed 100000/5786755 events (1.7%) - Rate: 10236.6 events/sec - ETA: 555.5 sec
# Processed 110000/5786755 events (1.9%) - Rate: 10446.7 events/sec - ETA: 543.4 sec
# Processed 120000/5786755 events (2.1%) - Rate: 10577.0 events/sec - ETA: 535.8 sec
# Processed 130000/5786755 events (2.2%) - Rate: 10752.8 events/sec - ETA: 526.1 sec
# Processed 140000/5786755 events (2.4%) - Rate: 10922.9 events/sec - ETA: 517.0 sec
# Processed 150000/5786755 events (2.6%) - Rate: 11127.8 events/sec - ETA: 506.5 sec
# Processed 160000/5786755 events (2.8%) - Rate: 11315.0 events/sec - ETA: 497.3 sec
# Processed 170000/5786755 events (2.9%) - Rate: 11485.8 events/sec - ETA: 489.0 sec
# Processed 180000/5786755 events (3.1%) - Rate: 11639.6 events/sec - ETA: 481.7 sec
# Processed 190000/5786755 events (3.3%) - Rate: 11781.7 events/sec - ETA: 475.0 sec
# Processed 200000/5786755 events (3.5%) - Rate: 11911.4 events/sec - ETA: 469.0 sec
# Processed 210000/5786755 events (3.6%) - Rate: 12031.1 events/sec - ETA: 463.5 sec
# Processed 220000/5786755 events (3.8%) - Rate: 12142.9 events/sec - ETA: 458.4 sec
# Processed 230000/5786755 events (4.0%) - Rate: 12240.7 events/sec - ETA: 454.0 sec
# Processed 240000/5786755 events (4.1%) - Rate: 12334.3 events/sec - ETA: 449.7 sec
# Processed 250000/5786755 events (4.3%) - Rate: 12424.6 events/sec - ETA: 445.6 sec
# Processed 260000/5786755 events (4.5%) - Rate: 12508.5 events/sec - ETA: 441.8 sec
# Processed 270000/5786755 events (4.7%) - Rate: 12587.6 events/sec - ETA: 438.3 sec
# Processed 280000/5786755 events (4.8%) - Rate: 12653.6 events/sec - ETA: 435.2 sec
# Processed 290000/5786755 events (5.0%) - Rate: 12720.8 events/sec - ETA: 432.1 sec
# Processed 300000/5786755 events (5.2%) - Rate: 12784.1 events/sec - ETA: 429.2 sec
# Processed 310000/5786755 events (5.4%) - Rate: 12847.4 events/sec - ETA: 426.3 sec
# Processed 320000/5786755 events (5.5%) - Rate: 12906.7 events/sec - ETA: 423.6 sec
# Processed 330000/5786755 events (5.7%) - Rate: 12962.4 events/sec - ETA: 421.0 sec
# Processed 340000/5786755 events (5.9%) - Rate: 13014.1 events/sec - ETA: 418.5 sec
# Processed 350000/5786755 events (6.0%) - Rate: 12992.6 events/sec - ETA: 418.5 sec
# Processed 360000/5786755 events (6.2%) - Rate: 12977.0 events/sec - ETA: 418.2 sec
# Processed 370000/5786755 events (6.4%) - Rate: 12963.0 events/sec - ETA: 417.9 sec
# Processed 380000/5786755 events (6.6%) - Rate: 12959.7 events/sec - ETA: 417.2 sec
# Processed 390000/5786755 events (6.7%) - Rate: 12960.7 events/sec - ETA: 416.4 sec
# Processed 400000/5786755 events (6.9%) - Rate: 13003.0 events/sec - ETA: 414.3 sec
# Processed 410000/5786755 events (7.1%) - Rate: 13043.0 events/sec - ETA: 412.2 sec
# Processed 420000/5786755 events (7.3%) - Rate: 13080.2 events/sec - ETA: 410.3 sec
# Processed 430000/5786755 events (7.4%) - Rate: 13117.1 events/sec - ETA: 408.4 sec
# Processed 440000/5786755 events (7.6%) - Rate: 13151.2 events/sec - ETA: 406.6 sec
# Processed 450000/5786755 events (7.8%) - Rate: 13185.5 events/sec - ETA: 404.7 sec
# Processed 460000/5786755 events (7.9%) - Rate: 13216.9 events/sec - ETA: 403.0 sec
# Processed 470000/5786755 events (8.1%) - Rate: 13248.7 events/sec - ETA: 401.3 sec
# Processed 480000/5786755 events (8.3%) - Rate: 13279.2 events/sec - ETA: 399.6 sec
# Processed 490000/5786755 events (8.5%) - Rate: 13307.8 events/sec - ETA: 398.0 sec
# Processed 500000/5786755 events (8.6%) - Rate: 13335.4 events/sec - ETA: 396.4 sec
# Processed 510000/5786755 events (8.8%) - Rate: 13362.6 events/sec - ETA: 394.9 sec
# Processed 520000/5786755 events (9.0%) - Rate: 13385.8 events/sec - ETA: 393.5 sec
# Processed 530000/5786755 events (9.2%) - Rate: 13409.6 events/sec - ETA: 392.0 sec
# Processed 540000/5786755 events (9.3%) - Rate: 13432.8 events/sec - ETA: 390.6 sec
# Processed 550000/5786755 events (9.5%) - Rate: 13458.5 events/sec - ETA: 389.1 sec
# Processed 560000/5786755 events (9.7%) - Rate: 13483.3 events/sec - ETA: 387.6 sec
# Processed 570000/5786755 events (9.9%) - Rate: 13506.7 events/sec - ETA: 386.2 sec
# Processed 580000/5786755 events (10.0%) - Rate: 13530.8 events/sec - ETA: 384.8 sec
# Processed 590000/5786755 events (10.2%) - Rate: 13553.2 events/sec - ETA: 383.4 sec
# Processed 600000/5786755 events (10.4%) - Rate: 13574.8 events/sec - ETA: 382.1 sec
# Processed 610000/5786755 events (10.5%) - Rate: 13596.5 events/sec - ETA: 380.7 sec
# Processed 620000/5786755 events (10.7%) - Rate: 13614.5 events/sec - ETA: 379.5 sec
# Processed 630000/5786755 events (10.9%) - Rate: 13630.5 events/sec - ETA: 378.3 sec
# Processed 640000/5786755 events (11.1%) - Rate: 13646.7 events/sec - ETA: 377.1 sec
# Processed 650000/5786755 events (11.2%) - Rate: 13661.3 events/sec - ETA: 376.0 sec
# Processed 660000/5786755 events (11.4%) - Rate: 13676.1 events/sec - ETA: 374.9 sec
# Processed 670000/5786755 events (11.6%) - Rate: 13690.5 events/sec - ETA: 373.7 sec
# Processed 680000/5786755 events (11.8%) - Rate: 13704.6 events/sec - ETA: 372.6 sec
# Processed 690000/5786755 events (11.9%) - Rate: 13716.0 events/sec - ETA: 371.6 sec
# Processed 700000/5786755 events (12.1%) - Rate: 13729.4 events/sec - ETA: 370.5 sec
# Processed 710000/5786755 events (12.3%) - Rate: 13743.3 events/sec - ETA: 369.4 sec
# Processed 720000/5786755 events (12.4%) - Rate: 13755.6 events/sec - ETA: 368.3 sec
# Processed 730000/5786755 events (12.6%) - Rate: 13765.5 events/sec - ETA: 367.4 sec
# Processed 740000/5786755 events (12.8%) - Rate: 13777.8 events/sec - ETA: 366.3 sec
# Processed 750000/5786755 events (13.0%) - Rate: 13790.6 events/sec - ETA: 365.2 sec
# Processed 760000/5786755 events (13.1%) - Rate: 13802.1 events/sec - ETA: 364.2 sec
# Processed 770000/5786755 events (13.3%) - Rate: 13813.8 events/sec - ETA: 363.2 sec
# Processed 780000/5786755 events (13.5%) - Rate: 13825.6 events/sec - ETA: 362.1 sec
# Processed 790000/5786755 events (13.7%) - Rate: 13836.4 events/sec - ETA: 361.1 sec
# Processed 800000/5786755 events (13.8%) - Rate: 13848.0 events/sec - ETA: 360.1 sec
# Processed 810000/5786755 events (14.0%) - Rate: 13857.3 events/sec - ETA: 359.1 sec
# Processed 820000/5786755 events (14.2%) - Rate: 13867.6 events/sec - ETA: 358.2 sec
# Processed 830000/5786755 events (14.3%) - Rate: 13878.0 events/sec - ETA: 357.2 sec
# Processed 840000/5786755 events (14.5%) - Rate: 13887.3 events/sec - ETA: 356.2 sec
# Processed 850000/5786755 events (14.7%) - Rate: 13897.2 events/sec - ETA: 355.2 sec
# Processed 860000/5786755 events (14.9%) - Rate: 13906.4 events/sec - ETA: 354.3 sec
# Processed 870000/5786755 events (15.0%) - Rate: 13915.4 events/sec - ETA: 353.3 sec
# Processed 880000/5786755 events (15.2%) - Rate: 13924.8 events/sec - ETA: 352.4 sec
# Processed 890000/5786755 events (15.4%) - Rate: 13933.7 events/sec - ETA: 351.4 sec
# Processed 900000/5786755 events (15.6%) - Rate: 13935.1 events/sec - ETA: 350.7 sec
# Processed 910000/5786755 events (15.7%) - Rate: 13917.0 events/sec - ETA: 350.4 sec
# Processed 920000/5786755 events (15.9%) - Rate: 13916.8 events/sec - ETA: 349.7 sec
# Processed 930000/5786755 events (16.1%) - Rate: 13925.1 events/sec - ETA: 348.8 sec
# Processed 940000/5786755 events (16.2%) - Rate: 13934.2 events/sec - ETA: 347.8 sec
# Processed 950000/5786755 events (16.4%) - Rate: 13942.0 events/sec - ETA: 346.9 sec
# Processed 960000/5786755 events (16.6%) - Rate: 13949.4 events/sec - ETA: 346.0 sec
# Processed 970000/5786755 events (16.8%) - Rate: 13957.0 events/sec - ETA: 345.1 sec
# Processed 980000/5786755 events (16.9%) - Rate: 13965.0 events/sec - ETA: 344.2 sec
# Processed 990000/5786755 events (17.1%) - Rate: 13972.4 events/sec - ETA: 343.3 sec
# Processed 1000000/5786755 events (17.3%) - Rate: 13979.9 events/sec - ETA: 342.4 sec
# Processed 1010000/5786755 events (17.5%) - Rate: 13987.4 events/sec - ETA: 341.5 sec
# Processed 1020000/5786755 events (17.6%) - Rate: 13994.6 events/sec - ETA: 340.6 sec
# Processed 1030000/5786755 events (17.8%) - Rate: 14001.6 events/sec - ETA: 339.7 sec
# Processed 1040000/5786755 events (18.0%) - Rate: 13986.9 events/sec - ETA: 339.4 sec
# Processed 1050000/5786755 events (18.1%) - Rate: 13961.2 events/sec - ETA: 339.3 sec
# Processed 1060000/5786755 events (18.3%) - Rate: 13943.4 events/sec - ETA: 339.0 sec
# Processed 1070000/5786755 events (18.5%) - Rate: 13922.1 events/sec - ETA: 338.8 sec
# Processed 1080000/5786755 events (18.7%) - Rate: 13906.2 events/sec - ETA: 338.5 sec
# Processed 1090000/5786755 events (18.8%) - Rate: 13900.7 events/sec - ETA: 337.9 sec
# Processed 1100000/5786755 events (19.0%) - Rate: 13899.3 events/sec - ETA: 337.2 sec
# Processed 1110000/5786755 events (19.2%) - Rate: 13890.6 events/sec - ETA: 336.7 sec
# Processed 1120000/5786755 events (19.4%) - Rate: 13894.4 events/sec - ETA: 335.9 sec
# Processed 1130000/5786755 events (19.5%) - Rate: 13896.3 events/sec - ETA: 335.1 sec
# Processed 1140000/5786755 events (19.7%) - Rate: 13903.3 events/sec - ETA: 334.2 sec
# Processed 1150000/5786755 events (19.9%) - Rate: 13904.6 events/sec - ETA: 333.5 sec
# Processed 1160000/5786755 events (20.0%) - Rate: 13912.0 events/sec - ETA: 332.6 sec
# Processed 1170000/5786755 events (20.2%) - Rate: 13917.6 events/sec - ETA: 331.7 sec
# Processed 1180000/5786755 events (20.4%) - Rate: 13924.4 events/sec - ETA: 330.8 sec
# Processed 1190000/5786755 events (20.6%) - Rate: 13931.3 events/sec - ETA: 330.0 sec
# Processed 1200000/5786755 events (20.7%) - Rate: 13938.1 events/sec - ETA: 329.1 sec
# Processed 1210000/5786755 events (20.9%) - Rate: 13944.5 events/sec - ETA: 328.2 sec
# Processed 1220000/5786755 events (21.1%) - Rate: 13951.3 events/sec - ETA: 327.3 sec
# Processed 1230000/5786755 events (21.3%) - Rate: 13957.5 events/sec - ETA: 326.5 sec
# Processed 1240000/5786755 events (21.4%) - Rate: 13963.4 events/sec - ETA: 325.6 sec
# Processed 1250000/5786755 events (21.6%) - Rate: 13969.7 events/sec - ETA: 324.8 sec
# Processed 1260000/5786755 events (21.8%) - Rate: 13975.5 events/sec - ETA: 323.9 sec
# Processed 1270000/5786755 events (21.9%) - Rate: 13982.0 events/sec - ETA: 323.0 sec
# Processed 1280000/5786755 events (22.1%) - Rate: 13987.7 events/sec - ETA: 322.2 sec
# Processed 1290000/5786755 events (22.3%) - Rate: 13993.9 events/sec - ETA: 321.3 sec
# Processed 1300000/5786755 events (22.5%) - Rate: 13999.8 events/sec - ETA: 320.5 sec
# Processed 1310000/5786755 events (22.6%) - Rate: 13999.5 events/sec - ETA: 319.8 sec
# Processed 1320000/5786755 events (22.8%) - Rate: 13992.2 events/sec - ETA: 319.2 sec
# Processed 1330000/5786755 events (23.0%) - Rate: 13997.4 events/sec - ETA: 318.4 sec
# Processed 1340000/5786755 events (23.2%) - Rate: 14001.7 events/sec - ETA: 317.6 sec
# Processed 1350000/5786755 events (23.3%) - Rate: 14007.2 events/sec - ETA: 316.7 sec
# Processed 1360000/5786755 events (23.5%) - Rate: 14007.0 events/sec - ETA: 316.0 sec
# Processed 1370000/5786755 events (23.7%) - Rate: 14012.5 events/sec - ETA: 315.2 sec
# Processed 1380000/5786755 events (23.8%) - Rate: 14018.0 events/sec - ETA: 314.4 sec
# Processed 1390000/5786755 events (24.0%) - Rate: 14023.0 events/sec - ETA: 313.5 sec
# Processed 1400000/5786755 events (24.2%) - Rate: 14028.0 events/sec - ETA: 312.7 sec
# Processed 1410000/5786755 events (24.4%) - Rate: 14033.1 events/sec - ETA: 311.9 sec
# Processed 1420000/5786755 events (24.5%) - Rate: 14038.2 events/sec - ETA: 311.1 sec
# Processed 1430000/5786755 events (24.7%) - Rate: 14043.5 events/sec - ETA: 310.2 sec
# Processed 1440000/5786755 events (24.9%) - Rate: 14048.7 events/sec - ETA: 309.4 sec
# Processed 1450000/5786755 events (25.1%) - Rate: 14053.5 events/sec - ETA: 308.6 sec
# Processed 1460000/5786755 events (25.2%) - Rate: 14058.1 events/sec - ETA: 307.8 sec
# Processed 1470000/5786755 events (25.4%) - Rate: 14062.7 events/sec - ETA: 307.0 sec
# Processed 1480000/5786755 events (25.6%) - Rate: 14067.6 events/sec - ETA: 306.1 sec
# Processed 1490000/5786755 events (25.7%) - Rate: 14072.3 events/sec - ETA: 305.3 sec
# Processed 1500000/5786755 events (25.9%) - Rate: 14076.6 events/sec - ETA: 304.5 sec
# Processed 1510000/5786755 events (26.1%) - Rate: 14080.9 events/sec - ETA: 303.7 sec
# Processed 1520000/5786755 events (26.3%) - Rate: 14084.8 events/sec - ETA: 302.9 sec
# Processed 1530000/5786755 events (26.4%) - Rate: 14089.3 events/sec - ETA: 302.1 sec
# Processed 1540000/5786755 events (26.6%) - Rate: 14093.5 events/sec - ETA: 301.3 sec
# Processed 1550000/5786755 events (26.8%) - Rate: 14097.5 events/sec - ETA: 300.5 sec
# Processed 1560000/5786755 events (27.0%) - Rate: 14101.8 events/sec - ETA: 299.7 sec
# Processed 1570000/5786755 events (27.1%) - Rate: 14106.1 events/sec - ETA: 298.9 sec
# Processed 1580000/5786755 events (27.3%) - Rate: 14105.3 events/sec - ETA: 298.2 sec
# Processed 1590000/5786755 events (27.5%) - Rate: 14109.0 events/sec - ETA: 297.5 sec
# Processed 1600000/5786755 events (27.6%) - Rate: 14102.6 events/sec - ETA: 296.9 sec
# Processed 1610000/5786755 events (27.8%) - Rate: 14098.0 events/sec - ETA: 296.3 sec
# Processed 1620000/5786755 events (28.0%) - Rate: 14091.6 events/sec - ETA: 295.7 sec
# Processed 1630000/5786755 events (28.2%) - Rate: 14089.2 events/sec - ETA: 295.0 sec
# Processed 1640000/5786755 events (28.3%) - Rate: 14091.8 events/sec - ETA: 294.3 sec
# Processed 1650000/5786755 events (28.5%) - Rate: 14095.0 events/sec - ETA: 293.5 sec
# Processed 1660000/5786755 events (28.7%) - Rate: 14098.1 events/sec - ETA: 292.7 sec
# Processed 1670000/5786755 events (28.9%) - Rate: 14101.4 events/sec - ETA: 291.9 sec
# Processed 1680000/5786755 events (29.0%) - Rate: 14104.4 events/sec - ETA: 291.2 sec
# Processed 1690000/5786755 events (29.2%) - Rate: 14107.8 events/sec - ETA: 290.4 sec
# Processed 1700000/5786755 events (29.4%) - Rate: 14110.9 events/sec - ETA: 289.6 sec
# Processed 1710000/5786755 events (29.6%) - Rate: 14114.5 events/sec - ETA: 288.8 sec
# Processed 1720000/5786755 events (29.7%) - Rate: 14118.0 events/sec - ETA: 288.1 sec
# Processed 1730000/5786755 events (29.9%) - Rate: 14120.3 events/sec - ETA: 287.3 sec
# Processed 1740000/5786755 events (30.1%) - Rate: 14123.6 events/sec - ETA: 286.5 sec
# Processed 1750000/5786755 events (30.2%) - Rate: 14126.8 events/sec - ETA: 285.8 sec
# Processed 1760000/5786755 events (30.4%) - Rate: 14130.2 events/sec - ETA: 285.0 sec
# Processed 1770000/5786755 events (30.6%) - Rate: 14128.6 events/sec - ETA: 284.3 sec
# Processed 1780000/5786755 events (30.8%) - Rate: 14131.6 events/sec - ETA: 283.5 sec
# Processed 1790000/5786755 events (30.9%) - Rate: 14133.4 events/sec - ETA: 282.8 sec
# Processed 1800000/5786755 events (31.1%) - Rate: 14130.8 events/sec - ETA: 282.1 sec
# Processed 1810000/5786755 events (31.3%) - Rate: 14124.5 events/sec - ETA: 281.6 sec
# Processed 1820000/5786755 events (31.5%) - Rate: 14127.1 events/sec - ETA: 280.8 sec
# Processed 1830000/5786755 events (31.6%) - Rate: 14130.5 events/sec - ETA: 280.0 sec
# Processed 1840000/5786755 events (31.8%) - Rate: 14133.7 events/sec - ETA: 279.2 sec
# Processed 1850000/5786755 events (32.0%) - Rate: 14137.1 events/sec - ETA: 278.5 sec
# Processed 1860000/5786755 events (32.1%) - Rate: 14140.2 events/sec - ETA: 277.7 sec
# Processed 1870000/5786755 events (32.3%) - Rate: 14143.1 events/sec - ETA: 276.9 sec
# Processed 1880000/5786755 events (32.5%) - Rate: 14146.2 events/sec - ETA: 276.2 sec
# Processed 1890000/5786755 events (32.7%) - Rate: 14149.3 events/sec - ETA: 275.4 sec
# Processed 1900000/5786755 events (32.8%) - Rate: 14152.5 events/sec - ETA: 274.6 sec
# Processed 1910000/5786755 events (33.0%) - Rate: 14155.6 events/sec - ETA: 273.9 sec
# Processed 1920000/5786755 events (33.2%) - Rate: 14158.7 events/sec - ETA: 273.1 sec
# Processed 1930000/5786755 events (33.4%) - Rate: 14158.9 events/sec - ETA: 272.4 sec
# Processed 1940000/5786755 events (33.5%) - Rate: 14159.1 events/sec - ETA: 271.7 sec
# Processed 1950000/5786755 events (33.7%) - Rate: 14158.2 events/sec - ETA: 271.0 sec
# Processed 1960000/5786755 events (33.9%) - Rate: 14158.6 events/sec - ETA: 270.3 sec
# Processed 1970000/5786755 events (34.0%) - Rate: 14158.6 events/sec - ETA: 269.6 sec
# Processed 1980000/5786755 events (34.2%) - Rate: 14157.8 events/sec - ETA: 268.9 sec
# Processed 1990000/5786755 events (34.4%) - Rate: 14160.6 events/sec - ETA: 268.1 sec
# Processed 2000000/5786755 events (34.6%) - Rate: 14163.9 events/sec - ETA: 267.4 sec
# Processed 2010000/5786755 events (34.7%) - Rate: 14166.9 events/sec - ETA: 266.6 sec
# Processed 2020000/5786755 events (34.9%) - Rate: 14170.1 events/sec - ETA: 265.8 sec
# Processed 2030000/5786755 events (35.1%) - Rate: 14173.0 events/sec - ETA: 265.1 sec
# Processed 2040000/5786755 events (35.3%) - Rate: 14175.7 events/sec - ETA: 264.3 sec
# Processed 2050000/5786755 events (35.4%) - Rate: 14178.8 events/sec - ETA: 263.5 sec
# Processed 2060000/5786755 events (35.6%) - Rate: 14181.4 events/sec - ETA: 262.8 sec
# Processed 2070000/5786755 events (35.8%) - Rate: 14184.1 events/sec - ETA: 262.0 sec
# Processed 2080000/5786755 events (35.9%) - Rate: 14187.0 events/sec - ETA: 261.3 sec
# Processed 2090000/5786755 events (36.1%) - Rate: 14189.8 events/sec - ETA: 260.5 sec
# Processed 2100000/5786755 events (36.3%) - Rate: 14192.3 events/sec - ETA: 259.8 sec
# Processed 2110000/5786755 events (36.5%) - Rate: 14194.7 events/sec - ETA: 259.0 sec
# Processed 2120000/5786755 events (36.6%) - Rate: 14197.3 events/sec - ETA: 258.3 sec
# Processed 2130000/5786755 events (36.8%) - Rate: 14199.7 events/sec - ETA: 257.5 sec
# Processed 2140000/5786755 events (37.0%) - Rate: 14202.5 events/sec - ETA: 256.8 sec
# Processed 2150000/5786755 events (37.2%) - Rate: 14204.6 events/sec - ETA: 256.0 sec
# Processed 2160000/5786755 events (37.3%) - Rate: 14206.6 events/sec - ETA: 255.3 sec
# Processed 2170000/5786755 events (37.5%) - Rate: 14208.9 events/sec - ETA: 254.5 sec
# Processed 2180000/5786755 events (37.7%) - Rate: 14209.8 events/sec - ETA: 253.8 sec
# Processed 2190000/5786755 events (37.8%) - Rate: 14212.4 events/sec - ETA: 253.1 sec
# Processed 2200000/5786755 events (38.0%) - Rate: 14214.5 events/sec - ETA: 252.3 sec
# Processed 2210000/5786755 events (38.2%) - Rate: 14215.9 events/sec - ETA: 251.6 sec
# Processed 2220000/5786755 events (38.4%) - Rate: 14218.0 events/sec - ETA: 250.9 sec
# Processed 2230000/5786755 events (38.5%) - Rate: 14220.4 events/sec - ETA: 250.1 sec
# Processed 2240000/5786755 events (38.7%) - Rate: 14222.7 events/sec - ETA: 249.4 sec
# Processed 2250000/5786755 events (38.9%) - Rate: 14225.1 events/sec - ETA: 248.6 sec
# Processed 2260000/5786755 events (39.1%) - Rate: 14226.9 events/sec - ETA: 247.9 sec
# Processed 2270000/5786755 events (39.2%) - Rate: 14229.5 events/sec - ETA: 247.1 sec
# Processed 2280000/5786755 events (39.4%) - Rate: 14230.5 events/sec - ETA: 246.4 sec
# Processed 2290000/5786755 events (39.6%) - Rate: 14232.4 events/sec - ETA: 245.7 sec
# Processed 2300000/5786755 events (39.7%) - Rate: 14234.5 events/sec - ETA: 245.0 sec
# Processed 2310000/5786755 events (39.9%) - Rate: 14236.6 events/sec - ETA: 244.2 sec
# Processed 2320000/5786755 events (40.1%) - Rate: 14238.8 events/sec - ETA: 243.5 sec
# Processed 2330000/5786755 events (40.3%) - Rate: 14240.4 events/sec - ETA: 242.7 sec
# Processed 2340000/5786755 events (40.4%) - Rate: 14242.3 events/sec - ETA: 242.0 sec
# Processed 2350000/5786755 events (40.6%) - Rate: 14244.2 events/sec - ETA: 241.3 sec
# Processed 2360000/5786755 events (40.8%) - Rate: 14246.1 events/sec - ETA: 240.5 sec
# Processed 2370000/5786755 events (41.0%) - Rate: 14248.0 events/sec - ETA: 239.8 sec
# Processed 2380000/5786755 events (41.1%) - Rate: 14249.8 events/sec - ETA: 239.1 sec
# Processed 2390000/5786755 events (41.3%) - Rate: 14251.8 events/sec - ETA: 238.3 sec
# Processed 2400000/5786755 events (41.5%) - Rate: 14253.5 events/sec - ETA: 237.6 sec
# Processed 2410000/5786755 events (41.6%) - Rate: 14254.8 events/sec - ETA: 236.9 sec
# Processed 2420000/5786755 events (41.8%) - Rate: 14256.6 events/sec - ETA: 236.2 sec
# Processed 2430000/5786755 events (42.0%) - Rate: 14256.1 events/sec - ETA: 235.5 sec
# Processed 2440000/5786755 events (42.2%) - Rate: 14252.9 events/sec - ETA: 234.8 sec
# Processed 2450000/5786755 events (42.3%) - Rate: 14246.6 events/sec - ETA: 234.2 sec
# Processed 2460000/5786755 events (42.5%) - Rate: 14243.9 events/sec - ETA: 233.6 sec
# Processed 2470000/5786755 events (42.7%) - Rate: 14241.9 events/sec - ETA: 232.9 sec
# Processed 2480000/5786755 events (42.9%) - Rate: 14243.3 events/sec - ETA: 232.2 sec
# Processed 2490000/5786755 events (43.0%) - Rate: 14245.3 events/sec - ETA: 231.4 sec
# Processed 2500000/5786755 events (43.2%) - Rate: 14247.4 events/sec - ETA: 230.7 sec
# Processed 2510000/5786755 events (43.4%) - Rate: 14249.1 events/sec - ETA: 230.0 sec
# Processed 2520000/5786755 events (43.5%) - Rate: 14250.9 events/sec - ETA: 229.2 sec
# Processed 2530000/5786755 events (43.7%) - Rate: 14252.5 events/sec - ETA: 228.5 sec
# Processed 2540000/5786755 events (43.9%) - Rate: 14254.2 events/sec - ETA: 227.8 sec
# Processed 2550000/5786755 events (44.1%) - Rate: 14256.0 events/sec - ETA: 227.0 sec
# Processed 2560000/5786755 events (44.2%) - Rate: 14257.6 events/sec - ETA: 226.3 sec
# Processed 2570000/5786755 events (44.4%) - Rate: 14257.9 events/sec - ETA: 225.6 sec
# Processed 2580000/5786755 events (44.6%) - Rate: 14258.8 events/sec - ETA: 224.9 sec
# Processed 2590000/5786755 events (44.8%) - Rate: 14259.9 events/sec - ETA: 224.2 sec
# Processed 2600000/5786755 events (44.9%) - Rate: 14260.9 events/sec - ETA: 223.5 sec
# Processed 2610000/5786755 events (45.1%) - Rate: 14262.6 events/sec - ETA: 222.7 sec
# Processed 2620000/5786755 events (45.3%) - Rate: 14264.5 events/sec - ETA: 222.0 sec
# Processed 2630000/5786755 events (45.4%) - Rate: 14266.0 events/sec - ETA: 221.3 sec
# Processed 2640000/5786755 events (45.6%) - Rate: 14267.5 events/sec - ETA: 220.6 sec
# Processed 2650000/5786755 events (45.8%) - Rate: 14269.1 events/sec - ETA: 219.8 sec
# Processed 2660000/5786755 events (46.0%) - Rate: 14270.6 events/sec - ETA: 219.1 sec
# Processed 2670000/5786755 events (46.1%) - Rate: 14272.1 events/sec - ETA: 218.4 sec
# Processed 2680000/5786755 events (46.3%) - Rate: 14274.0 events/sec - ETA: 217.7 sec
# Processed 2690000/5786755 events (46.5%) - Rate: 14275.2 events/sec - ETA: 216.9 sec
# Processed 2700000/5786755 events (46.7%) - Rate: 14276.6 events/sec - ETA: 216.2 sec
# Processed 2710000/5786755 events (46.8%) - Rate: 14278.1 events/sec - ETA: 215.5 sec
# Processed 2720000/5786755 events (47.0%) - Rate: 14279.0 events/sec - ETA: 214.8 sec
# Processed 2730000/5786755 events (47.2%) - Rate: 14280.6 events/sec - ETA: 214.0 sec
# Processed 2740000/5786755 events (47.3%) - Rate: 14282.0 events/sec - ETA: 213.3 sec
# Processed 2750000/5786755 events (47.5%) - Rate: 14283.2 events/sec - ETA: 212.6 sec
# Processed 2760000/5786755 events (47.7%) - Rate: 14284.6 events/sec - ETA: 211.9 sec
# Processed 2770000/5786755 events (47.9%) - Rate: 14282.8 events/sec - ETA: 211.2 sec
# Processed 2780000/5786755 events (48.0%) - Rate: 14284.1 events/sec - ETA: 210.5 sec
# Processed 2790000/5786755 events (48.2%) - Rate: 14285.4 events/sec - ETA: 209.8 sec
# Processed 2800000/5786755 events (48.4%) - Rate: 14285.3 events/sec - ETA: 209.1 sec
# Processed 2810000/5786755 events (48.6%) - Rate: 14284.4 events/sec - ETA: 208.4 sec
# Processed 2820000/5786755 events (48.7%) - Rate: 14285.6 events/sec - ETA: 207.7 sec
# Processed 2830000/5786755 events (48.9%) - Rate: 14286.7 events/sec - ETA: 207.0 sec
# Processed 2840000/5786755 events (49.1%) - Rate: 14288.2 events/sec - ETA: 206.2 sec
# Processed 2850000/5786755 events (49.3%) - Rate: 14289.3 events/sec - ETA: 205.5 sec
# Processed 2860000/5786755 events (49.4%) - Rate: 14286.7 events/sec - ETA: 204.9 sec
# Processed 2870000/5786755 events (49.6%) - Rate: 14286.3 events/sec - ETA: 204.2 sec
# Processed 2880000/5786755 events (49.8%) - Rate: 14287.5 events/sec - ETA: 203.4 sec
# Processed 2890000/5786755 events (49.9%) - Rate: 14288.9 events/sec - ETA: 202.7 sec
# Processed 2900000/5786755 events (50.1%) - Rate: 14290.3 events/sec - ETA: 202.0 sec
# Processed 2910000/5786755 events (50.3%) - Rate: 14291.4 events/sec - ETA: 201.3 sec
# Processed 2920000/5786755 events (50.5%) - Rate: 14292.7 events/sec - ETA: 200.6 sec
# Processed 2930000/5786755 events (50.6%) - Rate: 14294.1 events/sec - ETA: 199.9 sec
# Processed 2940000/5786755 events (50.8%) - Rate: 14295.7 events/sec - ETA: 199.1 sec
# Processed 2950000/5786755 events (51.0%) - Rate: 14297.4 events/sec - ETA: 198.4 sec
# Processed 2960000/5786755 events (51.2%) - Rate: 14298.6 events/sec - ETA: 197.7 sec
# Processed 2970000/5786755 events (51.3%) - Rate: 14299.7 events/sec - ETA: 197.0 sec
# Processed 2980000/5786755 events (51.5%) - Rate: 14300.1 events/sec - ETA: 196.3 sec
# Processed 2990000/5786755 events (51.7%) - Rate: 14300.7 events/sec - ETA: 195.6 sec
# Processed 3000000/5786755 events (51.8%) - Rate: 14301.5 events/sec - ETA: 194.9 sec
# Processed 3010000/5786755 events (52.0%) - Rate: 14298.6 events/sec - ETA: 194.2 sec
# Processed 3020000/5786755 events (52.2%) - Rate: 14292.4 events/sec - ETA: 193.6 sec
# Processed 3030000/5786755 events (52.4%) - Rate: 14283.6 events/sec - ETA: 193.0 sec
# Processed 3040000/5786755 events (52.5%) - Rate: 14269.5 events/sec - ETA: 192.5 sec
# Processed 3050000/5786755 events (52.7%) - Rate: 14256.9 events/sec - ETA: 192.0 sec
# Processed 3060000/5786755 events (52.9%) - Rate: 14245.7 events/sec - ETA: 191.4 sec
# Processed 3070000/5786755 events (53.1%) - Rate: 14242.4 events/sec - ETA: 190.8 sec
# Processed 3080000/5786755 events (53.2%) - Rate: 14241.9 events/sec - ETA: 190.1 sec
# Processed 3090000/5786755 events (53.4%) - Rate: 14241.6 events/sec - ETA: 189.4 sec
# Processed 3100000/5786755 events (53.6%) - Rate: 14233.5 events/sec - ETA: 188.8 sec
# Processed 3110000/5786755 events (53.7%) - Rate: 14225.4 events/sec - ETA: 188.2 sec
# Processed 3120000/5786755 events (53.9%) - Rate: 14223.7 events/sec - ETA: 187.5 sec
# Processed 3130000/5786755 events (54.1%) - Rate: 14220.9 events/sec - ETA: 186.8 sec
# Processed 3140000/5786755 events (54.3%) - Rate: 14214.7 events/sec - ETA: 186.2 sec
# Processed 3150000/5786755 events (54.4%) - Rate: 14212.3 events/sec - ETA: 185.5 sec
# Processed 3160000/5786755 events (54.6%) - Rate: 14205.4 events/sec - ETA: 184.9 sec
# Processed 3170000/5786755 events (54.8%) - Rate: 14201.0 events/sec - ETA: 184.3 sec
# Processed 3180000/5786755 events (55.0%) - Rate: 14199.5 events/sec - ETA: 183.6 sec
# Processed 3190000/5786755 events (55.1%) - Rate: 14194.0 events/sec - ETA: 182.9 sec
# Processed 3200000/5786755 events (55.3%) - Rate: 14185.9 events/sec - ETA: 182.3 sec
# Processed 3210000/5786755 events (55.5%) - Rate: 14182.3 events/sec - ETA: 181.7 sec
# Processed 3220000/5786755 events (55.6%) - Rate: 14175.5 events/sec - ETA: 181.1 sec
# Processed 3230000/5786755 events (55.8%) - Rate: 14172.3 events/sec - ETA: 180.4 sec
# Processed 3240000/5786755 events (56.0%) - Rate: 14170.5 events/sec - ETA: 179.7 sec
# Processed 3250000/5786755 events (56.2%) - Rate: 14168.2 events/sec - ETA: 179.0 sec
# Processed 3260000/5786755 events (56.3%) - Rate: 14166.3 events/sec - ETA: 178.4 sec
# Processed 3270000/5786755 events (56.5%) - Rate: 14164.2 events/sec - ETA: 177.7 sec
# Processed 3280000/5786755 events (56.7%) - Rate: 14163.1 events/sec - ETA: 177.0 sec
# Processed 3290000/5786755 events (56.9%) - Rate: 14160.6 events/sec - ETA: 176.3 sec
# Processed 3300000/5786755 events (57.0%) - Rate: 14156.1 events/sec - ETA: 175.7 sec
# Processed 3310000/5786755 events (57.2%) - Rate: 14148.9 events/sec - ETA: 175.0 sec
# Processed 3320000/5786755 events (57.4%) - Rate: 14137.2 events/sec - ETA: 174.5 sec
# Processed 3330000/5786755 events (57.5%) - Rate: 14102.2 events/sec - ETA: 174.2 sec
# Processed 3340000/5786755 events (57.7%) - Rate: 14078.0 events/sec - ETA: 173.8 sec
# Processed 3350000/5786755 events (57.9%) - Rate: 14046.8 events/sec - ETA: 173.5 sec
# Processed 3360000/5786755 events (58.1%) - Rate: 14018.5 events/sec - ETA: 173.1 sec
# Processed 3370000/5786755 events (58.2%) - Rate: 13995.4 events/sec - ETA: 172.7 sec
# Processed 3380000/5786755 events (58.4%) - Rate: 13967.8 events/sec - ETA: 172.3 sec
# Processed 3390000/5786755 events (58.6%) - Rate: 13940.3 events/sec - ETA: 171.9 sec
# Processed 3400000/5786755 events (58.8%) - Rate: 13911.1 events/sec - ETA: 171.6 sec
# Processed 3410000/5786755 events (58.9%) - Rate: 13887.3 events/sec - ETA: 171.1 sec
# Processed 3420000/5786755 events (59.1%) - Rate: 13852.5 events/sec - ETA: 170.9 sec
# Processed 3430000/5786755 events (59.3%) - Rate: 13817.7 events/sec - ETA: 170.6 sec
# Processed 3440000/5786755 events (59.4%) - Rate: 13786.5 events/sec - ETA: 170.2 sec
# Processed 3450000/5786755 events (59.6%) - Rate: 13764.4 events/sec - ETA: 169.8 sec
# Processed 3460000/5786755 events (59.8%) - Rate: 13744.9 events/sec - ETA: 169.3 sec
# Processed 3470000/5786755 events (60.0%) - Rate: 13734.8 events/sec - ETA: 168.7 sec
# Processed 3480000/5786755 events (60.1%) - Rate: 13725.3 events/sec - ETA: 168.1 sec
# Processed 3490000/5786755 events (60.3%) - Rate: 13707.1 events/sec - ETA: 167.6 sec
# Processed 3500000/5786755 events (60.5%) - Rate: 13698.8 events/sec - ETA: 166.9 sec
# Processed 3510000/5786755 events (60.7%) - Rate: 13692.1 events/sec - ETA: 166.3 sec
# Processed 3520000/5786755 events (60.8%) - Rate: 13676.0 events/sec - ETA: 165.7 sec
# Processed 3530000/5786755 events (61.0%) - Rate: 13643.7 events/sec - ETA: 165.4 sec
# Processed 3540000/5786755 events (61.2%) - Rate: 13611.3 events/sec - ETA: 165.1 sec
# Processed 3550000/5786755 events (61.3%) - Rate: 13577.2 events/sec - ETA: 164.7 sec
# Processed 3560000/5786755 events (61.5%) - Rate: 13550.2 events/sec - ETA: 164.3 sec
# Processed 3570000/5786755 events (61.7%) - Rate: 13524.4 events/sec - ETA: 163.9 sec
# Processed 3580000/5786755 events (61.9%) - Rate: 13490.8 events/sec - ETA: 163.6 sec
# Processed 3590000/5786755 events (62.0%) - Rate: 13465.6 events/sec - ETA: 163.1 sec
# Processed 3600000/5786755 events (62.2%) - Rate: 13435.2 events/sec - ETA: 162.8 sec
# Processed 3610000/5786755 events (62.4%) - Rate: 13405.9 events/sec - ETA: 162.4 sec
# Processed 3620000/5786755 events (62.6%) - Rate: 13377.4 events/sec - ETA: 162.0 sec
# Processed 3630000/5786755 events (62.7%) - Rate: 13346.5 events/sec - ETA: 161.6 sec
# Processed 3640000/5786755 events (62.9%) - Rate: 13317.7 events/sec - ETA: 161.2 sec
# Processed 3650000/5786755 events (63.1%) - Rate: 13284.1 events/sec - ETA: 160.9 sec
# Processed 3660000/5786755 events (63.2%) - Rate: 13258.9 events/sec - ETA: 160.4 sec
# Processed 3670000/5786755 events (63.4%) - Rate: 13222.3 events/sec - ETA: 160.1 sec
# Processed 3680000/5786755 events (63.6%) - Rate: 13174.1 events/sec - ETA: 159.9 sec
# Processed 3690000/5786755 events (63.8%) - Rate: 13132.3 events/sec - ETA: 159.7 sec
# Processed 3700000/5786755 events (63.9%) - Rate: 13089.0 events/sec - ETA: 159.4 sec
# Processed 3710000/5786755 events (64.1%) - Rate: 13059.2 events/sec - ETA: 159.0 sec
# Processed 3720000/5786755 events (64.3%) - Rate: 13050.0 events/sec - ETA: 158.4 sec
# Processed 3730000/5786755 events (64.5%) - Rate: 13043.5 events/sec - ETA: 157.7 sec
# Processed 3740000/5786755 events (64.6%) - Rate: 13034.7 events/sec - ETA: 157.0 sec
# Processed 3750000/5786755 events (64.8%) - Rate: 13026.5 events/sec - ETA: 156.4 sec
# Processed 3760000/5786755 events (65.0%) - Rate: 13016.0 events/sec - ETA: 155.7 sec
# Processed 3770000/5786755 events (65.1%) - Rate: 13006.2 events/sec - ETA: 155.1 sec
# Processed 3780000/5786755 events (65.3%) - Rate: 12993.4 events/sec - ETA: 154.4 sec
# Processed 3790000/5786755 events (65.5%) - Rate: 12990.4 events/sec - ETA: 153.7 sec
# Processed 3800000/5786755 events (65.7%) - Rate: 12986.6 events/sec - ETA: 153.0 sec
# Processed 3810000/5786755 events (65.8%) - Rate: 12976.0 events/sec - ETA: 152.3 sec
# Processed 3820000/5786755 events (66.0%) - Rate: 12967.2 events/sec - ETA: 151.7 sec
# Processed 3830000/5786755 events (66.2%) - Rate: 12956.2 events/sec - ETA: 151.0 sec
# Processed 3840000/5786755 events (66.4%) - Rate: 12944.4 events/sec - ETA: 150.4 sec
# Processed 3850000/5786755 events (66.5%) - Rate: 12930.3 events/sec - ETA: 149.8 sec
# Processed 3860000/5786755 events (66.7%) - Rate: 12926.8 events/sec - ETA: 149.1 sec
# Processed 3870000/5786755 events (66.9%) - Rate: 12921.8 events/sec - ETA: 148.3 sec
# Processed 3880000/5786755 events (67.0%) - Rate: 12917.4 events/sec - ETA: 147.6 sec
# Processed 3890000/5786755 events (67.2%) - Rate: 12915.3 events/sec - ETA: 146.9 sec
# Processed 3900000/5786755 events (67.4%) - Rate: 12916.7 events/sec - ETA: 146.1 sec
# Processed 3910000/5786755 events (67.6%) - Rate: 12918.0 events/sec - ETA: 145.3 sec
# Processed 3920000/5786755 events (67.7%) - Rate: 12920.6 events/sec - ETA: 144.5 sec
# Processed 3930000/5786755 events (67.9%) - Rate: 12923.1 events/sec - ETA: 143.7 sec
# Processed 3940000/5786755 events (68.1%) - Rate: 12924.3 events/sec - ETA: 142.9 sec
# Processed 3950000/5786755 events (68.3%) - Rate: 12925.5 events/sec - ETA: 142.1 sec
# Processed 3960000/5786755 events (68.4%) - Rate: 12928.2 events/sec - ETA: 141.3 sec
# Processed 3970000/5786755 events (68.6%) - Rate: 12930.5 events/sec - ETA: 140.5 sec
# Processed 3980000/5786755 events (68.8%) - Rate: 12925.0 events/sec - ETA: 139.8 sec
# Processed 3990000/5786755 events (69.0%) - Rate: 12915.1 events/sec - ETA: 139.1 sec
# Processed 4000000/5786755 events (69.1%) - Rate: 12901.1 events/sec - ETA: 138.5 sec
# Processed 4010000/5786755 events (69.3%) - Rate: 12881.6 events/sec - ETA: 137.9 sec
# Processed 4020000/5786755 events (69.5%) - Rate: 12860.9 events/sec - ETA: 137.4 sec
# Processed 4030000/5786755 events (69.6%) - Rate: 12843.4 events/sec - ETA: 136.8 sec
# Processed 4040000/5786755 events (69.8%) - Rate: 12824.4 events/sec - ETA: 136.2 sec
# Processed 4050000/5786755 events (70.0%) - Rate: 12806.3 events/sec - ETA: 135.6 sec
# Processed 4060000/5786755 events (70.2%) - Rate: 12779.2 events/sec - ETA: 135.1 sec
# Processed 4070000/5786755 events (70.3%) - Rate: 12750.7 events/sec - ETA: 134.6 sec
# Processed 4080000/5786755 events (70.5%) - Rate: 12711.3 events/sec - ETA: 134.3 sec
# Processed 4090000/5786755 events (70.7%) - Rate: 12680.7 events/sec - ETA: 133.8 sec
# Processed 4100000/5786755 events (70.9%) - Rate: 12648.4 events/sec - ETA: 133.4 sec
# Processed 4110000/5786755 events (71.0%) - Rate: 12525.9 events/sec - ETA: 133.9 sec
# Processed 4120000/5786755 events (71.2%) - Rate: 12292.6 events/sec - ETA: 135.6 sec
# Processed 4130000/5786755 events (71.4%) - Rate: 10749.8 events/sec - ETA: 154.1 sec

# %% [markdown]
# # Plot raw etof

# %%
if not coincident_imp_df.empty:
    # Convert ns time differences to us for plotting
    coincident_imp_df['dt_cathode_us'] = coincident_imp_df['dt_cathode_ns'] / 1000  # ns to μs
    coincident_imp_df['dt_anodeV_us'] = coincident_imp_df['dt_anodeV_ns'] / 1000    # ns to μs
    coincident_imp_df['dt_anodeH_us'] = coincident_imp_df['dt_anodeH_ns'] / 1000    # ns to μs
    
    plt.figure(figsize=(8, 4))
    fs = 18
    plt.scatter(coincident_imp_df['imp_xE'], coincident_imp_df['dt_anodeH_us'], 
                alpha=0.2, s=1, c='blue')
    plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
    plt.ylabel(r"AnodeH ToF ($\mu$s)", fontsize=fs)
    plt.title("Raw E-ToF", fontsize=fs+2)
    plt.xlim(0, 14000)
    plt.ylim(-1.7, -1.35)
    plt.grid(True, alpha=0.3)
    ax = plt.gca()
    ax.tick_params(axis='both', which='major', labelsize=fs-2)
#     plt.legend(fontsize=fs-4, frameon=True)
    plt.savefig("plots/raw_etof.pdf", dpi=1000)
else:
    print("No coincidences")

# %% [markdown]
# # Time correction for SHREC imp region boards

# %%
from matplotlib.lines import Line2D

# Get the recoil time in seconds
coincident_imp_df['t'] = coincident_imp_df['imp_timetag'] * 1e-12

# Define manual time offsets for the boards- board0 is master
manual_offsets = {
    0: 0,
    1: -0.045e-6,
    2: -0.065e-6,
    3: -0.085e-6,
    4: -0.105e-6,
    5: -0.125e-6,
}

# Calculate the corrected dt for the ppac plates in microseconds
# Staying consistent with xboard
coincident_imp_df['dt_anodeH_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_anodeH_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

coincident_imp_df['dt_anodeV_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_anodeV_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

coincident_imp_df['dt_cathode_us_corr'] = coincident_imp_df.apply(
    lambda row: row['dt_cathode_us'] + manual_offsets.get(row['xboard'], 0) * 1e6,
    axis=1
)

# Get boards
boards = sorted(coincident_imp_df['xboard'].unique())

plt.figure(figsize=(30,18))
fs=30

plt.subplot(221)
colors = plt.cm.tab10(np.linspace(0, 1, len(boards)))
legend_handles = []

for board, color in zip(boards, colors):
    # Filter the df for this board
    board_data = coincident_imp_df[coincident_imp_df['xboard'] == board]
    plt.scatter(board_data['imp_xE'], board_data['dt_anodeH_us'],
                s=2, alpha=0.2, color=color, label=f'Board {board}')
    legend_handles.append(Line2D([0], [0], marker='o', color='w', markersize=14, markerfacecolor=color, label=f'Board {board}'))
plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
plt.ylabel(r"ToF ($\mu$s)", fontsize=fs)
plt.title("E-ToF by implant board", fontsize=fs+2)
plt.xlim(0, 14000)
plt.ylim(-1.7, -1.35)
plt.grid(True, alpha=0.3)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
plt.legend(handles=legend_handles, fontsize=fs-4, frameon=True, shadow=True, facecolor='white')

plt.subplot(222)
for board, color in zip(boards, colors):
    # Filter the DataFrame for this board
    board_data = coincident_imp_df[coincident_imp_df['xboard'] == board]
    plt.scatter(board_data['imp_xE'], board_data['dt_anodeH_us_corr'],
                s=2, alpha=0.1, color=color, label=f'Board {board}')
    legend_handles.append(Line2D([0], [0], marker='o', color='w', markersize=14, markerfacecolor=color, label=f'Board {board}'))
plt.xlabel("SHREC implant energy (keV)", fontsize=fs)
plt.ylabel(r"ToF ($\mu$s)", fontsize=fs)
plt.title("Time corrected E-ToF by implant board", fontsize=fs+2)
plt.xlim(0, 14000)
plt.ylim(-1.7, -1.35)
plt.grid(True, alpha=0.3)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
# plt.legend(handles=legend_handles, fontsize=fs-4, frameon=True)


plt.savefig("plots/etof_by_board.png", dpi=1000)

# %% [markdown]
# # Decay events

# %%
# Set decay time window
min_corr_time = 0.00000001     # Minimum time after recoil to consider (in seconds)
max_corr_time = 20     # Maximum time after recoil to consider (in seconds)

# %%
# Build pixel history from the imp df & group the full implant event history by pixel (x,y)
pixel_groups = imp.groupby(['x', 'y'])
pixel_history = {pixel: group for pixel, group in pixel_groups}

# %%
# Create decay event list
decay_events = []

# %%
# For each recoil event, search for subsequent events in the same pixel from imp

# Create decay events list to hold events
decay_candidates = []  

# Loop through coincident imp (recoil-like) events
for recoil_idx, recoil in coincident_imp_df.iterrows():
    
    # Get the pixel for the recoil event
    pixel = (recoil['imp_x'], recoil['imp_y'])
    
    # Convert the recoil imp_timetag from picoseconds to seconds
    recoil_time_sec = recoil['imp_timetag'] / 1e12
    
    # Check if there are any events in the same pixel in the imp region df.
    if pixel not in pixel_history:
        continue  # Skip if no events are found for this pixel
    
    # Get the time sorted events for this pixel from imp
    pixel_df = pixel_history[pixel]
    
    # Get the pixel time values as a sorted array
    time_array = pixel_df['t'].values # This is in seconds
    
    # Define the lower and upper bounds for candidate decay events in seconds
    lower_bound = recoil_time_sec + min_corr_time
    upper_bound = recoil_time_sec + max_corr_time
    
    # Use binary search to find the index positions in the time array
    start_idx = np.searchsorted(time_array, lower_bound, side='left')
    end_idx = np.searchsorted(time_array, upper_bound, side='right')
    
    # If events exist in the correlation window, add them as candidate decay events
    if start_idx < end_idx:
        
        candidate_events = pixel_df.iloc[start_idx:end_idx].copy()
        
        # Record the associated recoil info for later
        candidate_events['recoil_index'] = recoil_idx 
        candidate_events['recoil_time_sec'] = recoil_time_sec
        decay_candidates.append(candidate_events) # add decay candidates to list

# Combine all candidate decay events into a single df
if decay_candidates:
    decay_candidates_df = pd.concat(decay_candidates, ignore_index=True)
else:
    decay_candidates_df = pd.DataFrame()

# Display the first few decay candidates
print(decay_candidates_df.head())

# %% [markdown]
# # PPAC Anticoincidence check for decays
#
# Check the candidate decay is in the non-coincident list, do this by merging on pixel?

# %%
# Check the unique (x, y, t) keys in each DataFrame
print("Decay candidates unique keys:", decay_candidates_df[['x', 'y', 't']].drop_duplicates().shape)
print("Non-coincident unique keys:", non_coincident_imp_df[['x', 'y', 't']].drop_duplicates().shape)

# %%
if not decay_candidates_df.empty:
    # Drop duplicate rows based on x and y in non_coincident_imp_df
    non_coincident_clean = non_coincident_imp_df[['x', 'y']].drop_duplicates()
    
    # every row in decay_candidates_df is kept, 
    # and we add data from non_coincident_clean where there is a match on x and y
    decay_candidates_df = decay_candidates_df.merge(
        non_coincident_clean, 
        on=['x', 'y'],
        how='left',
        indicator='ppac_flag'
    )
    
    # If an event from decay_candidates_df finds a matching row in non_coincident_clean, 
    # ppac_flag will be set to "both".
    # If there is no match (i.e. PPAC signal), ppac_flag will be 'left_only'
    decay_candidates_df['is_clean'] = decay_candidates_df['ppac_flag'] == 'both'

print(decay_candidates_df['is_clean'].value_counts())
print(decay_candidates_df.head())

# %% [markdown]
# # Decay KHS

# %%
# Find the log time between implant and decay event
decay_candidates_df['log_dt'] = np.log(abs(decay_candidates_df['t'] - decay_candidates_df['recoil_time_sec']))

# %%
# Plot the 2d KHS hist
fs = 18
plt.figure(figsize=(8,4))
plt.hist2d(decay_candidates_df['yE'], decay_candidates_df['log_dt'], 
           bins=((500),(50)), range=((0,10000),(-3,3)), cmin=1)
plt.xlabel('Decay energy (keV)', fontsize=fs)
plt.ylabel(r'Ln($\Delta$t/ s)/ 10 keV', fontsize=fs)
plt.title('Decay events: KHS vs energy', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4)
plt.savefig('plots/decay_khs.pdf', dpi=1000)

# %% [markdown]
# # EVR-a correlations

# %%
# Alpha energy, time gates
# Recoil energy gates

alpha_energy_min = 8100    # Minimum alpha energy (keV)
alpha_energy_max = 8400    # Maximum alpha energy (keV)

recoil_energy_min = 2000   # Minimum recoil energy (keV)
recoil_energy_max = 8099  # Maximum recoil energy (keV) 

alpha_corr_min = 0.08    # Minimum time difference in seconds 
alpha_corr_max = 10         # Maximum time difference in seconds

# %%
# Filter alpha candidates by energy
filtered_alpha_candidates = decay_candidates_df[
    (decay_candidates_df['xE'] >= alpha_energy_min) & 
    (decay_candidates_df['xE'] <= alpha_energy_max)
].copy()

# %%
# just making sure we have t
if 't' not in filtered_alpha_candidates.columns:
    filtered_alpha_candidates['t'] = filtered_alpha_candidates['timetag'] / 1e12

# %%
# for each alpha candidate, find the preceeding recoil in same pixel

# initialising cols in the df
filtered_alpha_candidates['closest_recoil_index'] = np.nan
filtered_alpha_candidates['recoil_time'] = np.nan
filtered_alpha_candidates['time_difference'] = np.nan
filtered_alpha_candidates['recoil_energy'] = np.nan

# loop through the alpha candidates
for idx, alpha in filtered_alpha_candidates.iterrows():
    pixel_x = alpha['x']
    pixel_y = alpha['y']
    alpha_time = alpha['t']
    
    # Retrieve all recoil events from the same pixel
    recoils_in_pixel = coincident_imp_df[
        (coincident_imp_df['imp_x'] == pixel_x) & (coincident_imp_df['imp_y'] == pixel_y)
    ]
    
    # apply recoil energy gate
    recoils_in_pixel = recoils_in_pixel[
        (recoils_in_pixel['imp_xE'] >= recoil_energy_min) &
        (recoils_in_pixel['imp_xE'] <= recoil_energy_max)
    ]
    
    # Only consider recoils that occurred before the alpha event
    recoils_before = recoils_in_pixel[recoils_in_pixel['t'] < alpha_time]
    
    if not recoils_before.empty:
        
        # its good to work with copies... compute the time difference between r-a
        recoils_before = recoils_before.copy()
        recoils_before['time_diff'] = alpha_time - recoils_before['t']
        
        # make sure the r-a fits in the coincidence window
        recoils_in_window = recoils_before[
            (recoils_before['time_diff'] >= alpha_corr_min) &
            (recoils_before['time_diff'] <= alpha_corr_max)
        ]
        
        if not recoils_in_window.empty:
            # there might be multiple correlations, so choose the one with the smallest time difference
            closest_recoil = recoils_in_window.loc[recoils_in_window['time_diff'].idxmin()]
            filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = closest_recoil.name
            filtered_alpha_candidates.at[idx, 'recoil_time'] = closest_recoil['t']
            filtered_alpha_candidates.at[idx, 'time_difference'] = closest_recoil['time_diff']
            filtered_alpha_candidates.at[idx, 'recoil_energy'] = closest_recoil['imp_xE']
        else:
            filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = np.nan
            filtered_alpha_candidates.at[idx, 'recoil_time'] = np.nan
            filtered_alpha_candidates.at[idx, 'time_difference'] = np.nan
            filtered_alpha_candidates.at[idx, 'recoil_energy'] = np.nan
    else:
        filtered_alpha_candidates.at[idx, 'closest_recoil_index'] = np.nan
        filtered_alpha_candidates.at[idx, 'recoil_time'] = np.nan
        filtered_alpha_candidates.at[idx, 'time_difference'] = np.nan
        filtered_alpha_candidates.at[idx, 'recoil_energy'] = np.nan

# %%
# Build the correlation dataframe
correlated_events = filtered_alpha_candidates.dropna(subset=['recoil_time']).copy()
print("Number of correlated alpha-recoil events:", len(correlated_events))
print(correlated_events.head())

# %%
# Merge the recoil and alpha info together, and rename things for clarity
recoil_rename = {
    'imp_timetag': 'rec_timetag',
    'imp_x': 'rec_x',
    'imp_y': 'rec_y',
    'imp_tagx': 'rec_tagx',
    'imp_tagy': 'rec_tagy',
    'imp_nfile': 'rec_nfile',
    'imp_tdelta': 'rec_tdelta',
    'imp_nX': 'rec_nX',
    'imp_nY': 'rec_nY',
    'imp_xE': 'rec_xE',
    'imp_yE': 'rec_yE',
    'xboard': 'rec_xboard',
    'yboard': 'rec_yboard',
    'cathode_timetag': 'rec_cathode_timetag',
    'cathode_energy': 'rec_cathode_energy',
    'cathode_board': 'rec_cathode_board',
    'cathode_channel': 'rec_cathode_channel',
    'cathode_nfile': 'rec_cathode_nfile',
    'anodeV_timetag': 'rec_anodeV_timetag',
    'anodeV_energy': 'rec_anodeV_energy',
    'anodeV_board': 'rec_anodeV_board',
    'anodeV_channel': 'rec_anodeV_channel',
    'anodeV_nfile': 'rec_anodeV_nfile',
    'anodeH_timetag': 'rec_anodeH_timetag',
    'anodeH_energy': 'rec_anodeH_energy',
    'anodeH_board': 'rec_anodeH_board',
    'anodeH_channel': 'rec_anodeH_channel',
    'anodeH_nfile': 'rec_anodeH_nfile',
    'dt_cathode_ps': 'rec_dt_cathode_ps',
    'dt_anodeV_ps': 'rec_dt_anodeV_ps',
    'dt_anodeH_ps': 'rec_dt_anodeH_ps',
    'dt_cathode_ns': 'rec_dt_cathode_ns',
    'dt_anodeV_ns': 'rec_dt_anodeV_ns',
    'dt_anodeH_ns': 'rec_dt_anodeH_ns',
    'dt_cathode_us': 'rec_dt_cathode_us',
    'dt_anodeV_us': 'rec_dt_anodeV_us',
    'dt_anodeH_us': 'rec_dt_anodeH_us',
    't': 'rec_t',
    'dt_anodeH_us_corr': 'rec_dt_anodeH_us_corr',
    'dt_anodeV_us_corr': 'rec_dt_anodeV_us_corr',
    'dt_cathode_us_corr': 'rec_dt_cathode_us_corr'
}

alpha_rename = {
    't': 'alpha_t',
    'x': 'alpha_x',
    'y': 'alpha_y',
    'tagx': 'alpha_tagx',
    'tagy': 'alpha_tagy',
    'nfile': 'alpha_nfile',
    'xboard': 'alpha_xboard',
    'yboard': 'alpha_yboard',
    'tdelta': 'alpha_tdelta',
    'nX': 'alpha_nX',
    'nY': 'alpha_nY',
    'xE': 'alpha_xE',
    'yE': 'alpha_yE',
    'event_type': 'alpha_event_type',
    'recoil_index': 'alpha_recoil_index',
    'recoil_time_sec': 'alpha_recoil_time',
    'ppac_flag': 'alpha_ppac_flag',
    'is_clean': 'alpha_is_clean',
    'log_dt': 'alpha_log_dt',
    # Also include new computed cols
    'closest_recoil_index': 'alpha_closest_recoil_index',
    'recoil_time': 'alpha_recoil_time_calculated',
    'time_difference': 'alpha_time_difference',
    'recoil_energy': 'alpha_recoil_energy'
}

# Rename columns in the recoil df
recoil_df_renamed = coincident_imp_df.copy().rename(columns=recoil_rename)

# Rename columns in the alpha df
alpha_df_renamed = correlated_events.copy().rename(columns=alpha_rename)

# Merge the two dfs using the recoil index
final_correlated_df = alpha_df_renamed.merge(
    recoil_df_renamed,
    left_on='alpha_recoil_index',
    right_index=True,
    how='left'
)

# %%
# print some check stuff
print("Final correlated Events df:")
print(final_correlated_df.head())
print("Checking pixel matches (alpha vs. recoil):")
print(final_correlated_df[['alpha_x', 'alpha_y', 'rec_x', 'rec_y']].head())

# %% [markdown]
# # Plotting correlated stuff

# %%
# log decay time

final_correlated_df['log_dt'] = np.log10(np.abs(final_correlated_df['alpha_t'] - final_correlated_df['rec_t']))
final_correlated_df['rec_alpha_time'] =np.abs(final_correlated_df['alpha_t'] - final_correlated_df['rec_t'])
fs = 16
plt.figure(figsize=(13,7))

plt.subplot(221)
plt.scatter(final_correlated_df['alpha_xE'], final_correlated_df['rec_alpha_time'],
            s=10, color='red', alpha=0.7, label=r'Correlated $\alpha$')
plt.xlabel('SHREC alpha X-Energy (keV)', fontsize=fs)
# plt.ylabel(r'log(dt/s)', fontsize=fs)
plt.ylabel(r'Correlation time (s)', fontsize=fs)
plt.xlim(8100, 8400)
plt.yscale('log')
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4 )
plt.legend(fontsize=fs-4, loc='lower left', frameon=True)
plt.ylim(0.001,20)
plt.title(r'Correlation time vs $\alpha$ energy', fontsize=fs+2)

plt.subplot(222)
plt.hist2d(decay_candidates_df['xE'], decay_candidates_df['log_dt'], 
           bins=((500),(50)), range=((5000,10000),(-3,3)), cmin=1)
plt.fill_betweenx(y=[np.log(alpha_corr_min), np.log(alpha_corr_max)], x1=alpha_energy_min, x2=alpha_energy_max, 
                  color='g', alpha=0.2, label=r'$^{246}$Fm gate')
plt.xlabel('Decay energy (keV)', fontsize=fs)
plt.ylabel(r'Ln($\Delta$t/ s)/ 10 keV', fontsize=fs)
plt.title('Decay events: KHS vs energy', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', labelsize=fs-4)
plt.legend(fontsize=fs-4, loc='upper left', frameon=True, facecolor='white', shadow=True)




plt.savefig('plots/log_time_corr_alphas.pdf', dpi=300)

# %%
# Correlated etof

plt.figure(figsize=(8,4))
fs = 18
plt.hexbin(coincident_imp_df['imp_xE'], coincident_imp_df['dt_anodeH_us_corr'], 
           gridsize=200, extent=(0, 10000, -1.7, -1.5), mincnt=1, cmap='viridis', alpha=0.7)
plt.scatter(final_correlated_df['rec_xE'], final_correlated_df['rec_dt_anodeH_us_corr'],
            color='red', alpha=0.4, s=20, label=r'$\alpha$-tagged')  
legend_marker = Line2D([0], [0], marker='o', color='w', markersize=6, 
                        markerfacecolor='red', label=r'$\alpha$-tagged')
plt.ylim(-1.625, -1.49)
plt.xlim(0, 10000)
plt.xlabel('SHREC implant energy (keV)', fontsize=fs)
plt.ylabel(r'ToF ($\mu$s/ 50keV)', fontsize=fs)
plt.title(r'$\alpha$-correlated E-ToF', fontsize=fs+2)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
plt.legend(handles=[legend_marker], loc='lower right', fontsize=fs-2, frameon=True, facecolor='white', shadow=True)
plt.savefig('plots/correlated_etof.pdf', dpi=300)

# %%
# correlated beam spot
plt.figure(figsize=(8,3))
fs = 18
plt.hist2d(final_correlated_df['rec_x'], final_correlated_df['rec_y'], 
           bins=((175),(61)), range=((-1,174),(-1,60)), cmin=1)
# plt.xlim(0, 10000)
plt.xlabel('x-strip', fontsize=fs)
plt.ylabel(r'y-strip', fontsize=fs)
plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)
# plt.legend(loc='lower right', fontsize=fs-2, frameon=True)
plt.savefig('plots/correlated_stripX_stripY.pdf', dpi=300)

# %%
# beam spot projections
# correlated beam spot

plt.figure(figsize=(12,6))
fs = 18

plt.subplot(221)
plt.hist(final_correlated_df['rec_x'], histtype='step', bins=175, range=(-1,174))
plt.xlabel('x-strip', fontsize=fs)
plt.ylabel(r'Counts', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.subplot(222)
plt.hist(final_correlated_df['rec_y'], histtype='step',bins=60, range=(-1,59))
plt.xlabel('y-strip', fontsize=fs)
plt.ylabel(r'Counts', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)


plt.savefig('plots/correlated_beam_spot_projections.pdf', dpi=300)

# %%
# Recoil and alpha energies

plt.figure(figsize=(12,6))
fs = 18

plt.subplot(221)
plt.hist(final_correlated_df['alpha_xE'], histtype='step', bins=60, range=(8100,8400))
plt.xlabel('Alpha energy (keV)', fontsize=fs)
plt.ylabel(r'Counts/ 10keV', fontsize=fs)
# plt.title(r'$\alpha$ correlated, recoil beam spot', fontsize=fs+2)
# plt.colorbar()
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.subplot(222)
plt.hist(final_correlated_df['rec_xE'], histtype='step',bins=175, range=(2000,9000))
plt.xlabel('Recoil energy (keV)', fontsize=fs)
plt.ylabel(r'Counts/ 40keV', fontsize=fs)
ax = plt.gca()
ax.tick_params(axis='both', which='major', labelsize=fs-2)

plt.savefig('plots/rec_alpha_energy_projections.pdf', dpi=300)
